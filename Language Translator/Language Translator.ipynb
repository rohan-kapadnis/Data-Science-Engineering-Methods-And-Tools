# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.core.display import HTML
from itertools import chain
from collections import Counter, defaultdict, namedtuple, OrderedDict
from pomegranate import State, HiddenMarkovModel, DiscreteDistribution
import os
from io import BytesIO
from itertools import chain
import random

# %%
def read_data(filename):
    """Read tagged sentence data"""
    with open(filename, 'r', encoding='utf-8', errors='ignore') as f:
        sentence_lines = [l.split("\n") for l in f.read().split("\n\n")]
    return OrderedDict(((s[0], Sentence(*zip(*[l.strip().split("\t")
                        for l in s[1:]]))) for s in sentence_lines if s[0]))

def read_tags(filename):
    """Read a list of word tag classes"""
    with open(filename, 'r') as f:
        tags = f.read().split("\n")
    return frozenset(tags)

Sentence = namedtuple("Sentence", "words tags")

# %% [markdown]
# Let's read in the Brown corpus to see if our python code works out:

# %%
tag = read_tags("english.txt")
sentence1 = read_data("hindi.txt")
sentence1
# Out:
# OrderedDict([('b100-5507',
#               Sentence(words=('वे', 'हो', 'पर', 'एक', 'है', 'इस', 'करता है', 'ठीक कर', 'छह', 'पढ़ा', 'हाथ', 'वे', 'हो', 'पर', 'एक', 'है', 'इस', 'करता है', 'ठीक कर', 'छह', 'पढ़ा', 'हाथ'), tags=('they', 'be', 'at', 'one', 'have', 'this', 'does', 'fix', 'six', 'read', 'hand', 'they', 'be', 'at', 'one', 'have', 'this', 'does', 'fix', 'six', 'read', 'hand'))),
#              ('b100-935',
#               Sentence(words=('वे', 'हो', 'पर', 'एक', 'है', 'इस', 'करता है', 'ठीक कर', 'छह', 'पढ़ा', 'हाथ', 'आधा', 'किमी ', 'की ', 'लंबाई ', 'पर ', 'देश', 'विशेष', 'जहाँ ', 'केवल ', 'मां', 'के ', 'पट ', 'खुलने ', 'और ', 'बंद ', 'होने ', 'के ', 'दिन ', 'ही ', 'पूजा ', 'किया ', 'जाता ', 'है'), tags=('they', 'be', 'at', 'one', 'have', 'this', 'does', 'fix', 'six', 'read', 'hand', 'half', 'km', 'a', 'length', 'at', 'country', 'special', 'where', 'only', 'mother', 'is', 'door', 'opening', 'and', 'closing', 'done', 'is', 'day', 'only', 'pray', 'done', 'is', 'done'))),
#              ('b100-30614',
#               Sentence(words=('आधा', 'किमी ', 'की ', 'लंबाई ', 'पर ', 'देश', 'विशेष', 'जहाँ ', 'केवल ', 'मां', 'के ', 'पट ', 'खुलने ', 'और ', 'बंद ', 'होने ', 'के ', 'दिन ', 'ही ', 'पूजा ', 'किया ', 'जाता ', 'है', 'आधा', 'किमी ', 'की ', 'लंबाई ', 'पर ', 'देश', 'विशेष', 'जहाँ ', 'केवल ', 'मां', 'के ', 'पट ', 'खुलने ', 'और ', 'बंद ', 'होने ', 'के ', 'दिन ', 'ही ', 'पूजा ', 'किया ', 'जाता ', 'है', 'पृथ्वी', 'का ', 'स्थान ', 'हवा', 'में ', 'टुकड़ा', 'अथवा ', 'घर', 'के ', 'रूप ', 'में ', 'महत्वपूर्ण ', 'है', 'पृथ्वी', 'का ', 'स्थान ', 'हवा', 'में ', 'टुकड़ा', 'अथवा ', 'घर', 'के ', 'रूप ', 'में ', 'महत्वपूर्ण ', 'है', 'पृथ्वी', 'का ', 'स्थान ', 'हवा', 'में ', 'टुकड़ा', 'अथवा ', 'घर', 'के ', 'रूप ', 'में ', 'महत्वपूर्ण ', 'है'), tags=('half', 'km', 'a', 'length', 'at', 'country', 'special', 'where', 'only', 'mother', 'is', 'door', 'opening', 'and', 'closing', 'done', 'is', 'day', 'only', 'pray', 'done', 'is', 'done', 'half', 'km', 'a', 'length', 'at', 'country', 'special', 'where', 'only', 'mother', 'is', 'door', 'opening', 'and', 'closing', 'done', 'is', 'day', 'only', 'pray', 'done', 'is', 'done', 'earth', 'is', 'place', 'wind', 'as', 'piece', 'or', 'house', 'is', 'way', 'as', 'important', 'is', 'earth', 'is', 'place', 'wind', 'as', 'piece', 'or', 'house', 'is', 'way', 'as', 'important', 'is', 'earth', 'is', 'place', 'wind', 'as', 'piece', 'or', 'house', 'is', 'way', 'as', 'important', 'is'))),
#              ('b100-6250',
#               Sentence(words=('सभी ', 'पर्व ', 'ओर ', 'त्योहार ', 'परस्पर ', 'प्रेम ', 'भाईचारा ', 'मिलाना ', 'मिलाप ', 'संदेश ', 'देता ', 'हे ', 'दूसरे ', 'शब्दों ', 'में ', 'सभी ', 'पर्वो  ', 'त्योहार', 'से ', 'हमे ', 'सदाचार  ', 'सहानुभूति ', 'परस्पर ', 'सहयोग ', 'और ', 'मानवता ', 'की ', 'भावना ', 'प्राप्त ', 'होती ', 'है', 'यह ', 'ध्यान ', 'देने ', 'की ', 'बात ', 'हैं', 'कि ', 'कोई ', 'भी ', 'पर्व', 'या ', 'त्योहार ', 'चाहे ', 'स्वदेशी ', 'हो ', 'या ', 'विदेशी ', 'हो', 'चाहे ', 'गरीब ', 'हो ', 'या ', 'अमीर ', 'वर्ग ', 'का ', 'क्यों ', 'ना ', 'हो ', 'उसमे ', 'उपर्युक्त ', 'विशेषता ', 'ओर ', 'श्रेष्ठता ', 'अवश्य ', 'होती ', 'है'), tags=('everyone', 'festivals', 'and', 'festival', 'mutual', 'love', 'brotherhood', 'harmonize', 'meet', 'message', 'gives', 'does', 'other', 'words', 'in', 'everyone', 'festivals', 'festivals', 'get', 'we', 'virtue', 'sympathy', 'mutual', 'cooperation', 'and', 'humanity', 'it', 'sense', 'gives', 'get', 'does', 'it', 'worth', 'noting', 'is', 'noting', 'is', 'That', 'any', 'any', 'festival', 'or', 'festival', 'it', 'indigenous', 'be', 'or', 'foreign', 'be', 'it', 'poor', 'be', 'or', 'rich', 'class', 'it', 'be', 'whether', 'be', 'it', 'above', 'characteristic', 'and', 'superiority', 'must', 'have', 'it'))),
#              ('b100-39560',
#               Sentence(words=('इराक  ', 'के', 'विदेश', 'मंत्री', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'मजाक', 'उड़ाया', 'जिसमें', 'अमरीका', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा', 'आतंकवाद', 'एक', 'ऐसी', 'समस्या', 'जिसने', 'न', 'केवल', 'भारत', 'अपितु', 'पूरे', 'विश्व', 'को', 'अपने', 'लपेटे', 'ले', 'रखा', 'है'), tags=('Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has'))),
#              ('b100-3367',
#               Sentence(words=('क्रिसमस ', 'दिसम्बर ', 'का ', 'पर्व ', 'या ', 'त्योहार ', 'है', 'सभी ', 'पर्व ', 'ओर ', 'त्योहार ', 'परस्पर ', 'प्रेम ', 'भाईचारा ', 'मिलाना ', 'मिलाप ', 'संदेश ', 'देता ', 'हे ', 'दूसरे ', 'शब्दों ', 'में ', 'सभी ', 'पर्वो  ', 'त्योहार', 'से ', 'हमे ', 'सदाचार  ', 'सहानुभूति ', 'परस्पर ', 'सहयोग ', 'और ', 'मानवता ', 'की ', 'भावना ', 'प्राप्त ', 'होती ', 'है', 'यह ', 'ध्यान ', 'देने ', 'की ', 'बात ', 'हैं', 'कि ', 'कोई ', 'भी ', 'पर्व', 'या ', 'त्योहार ', 'चाहे ', 'स्वदेशी ', 'हो ', 'या ', 'विदेशी ', 'हो', 'चाहे ', 'गरीब ', 'हो ', 'या ', 'अमीर ', 'वर्ग ', 'का ', 'क्यों ', 'ना ', 'हो ', 'उसमे ', 'उपर्युक्त ', 'विशेषता ', 'ओर ', 'श्रेष्ठता ', 'अवश्य ', 'होती ', 'है'), tags=('Christmas', 'December', 'is', 'festival', 'or', 'festival', 'is', 'everyone', 'festivals', 'and', 'festival', 'mutual', 'love', 'brotherhood', 'harmonize', 'meet', 'message', 'gives', 'does', 'other', 'words', 'in', 'everyone', 'festivals', 'festivals', 'get', 'we', 'virtue', 'sympathy', 'mutual', 'cooperation', 'and', 'humanity', 'it', 'sense', 'gives', 'get', 'does', 'it', 'worth', 'noting', 'is', 'noting', 'is', 'That', 'any', 'any', 'festival', 'or', 'festival', 'it', 'indigenous', 'be', 'or', 'foreign', 'be', 'it', 'poor', 'be', 'or', 'rich', 'class', 'it', 'be', 'whether', 'be', 'it', 'above', 'characteristic', 'and', 'superiority', 'must', 'have', 'it'))),
#              ('b100-3565',
#               Sentence(words=('इराक  ', 'के', 'विदेश', 'मंत्री', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'मजाक', 'उड़ाया', 'जिसमें', 'अमरीका', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा', 'आतंकवाद', 'एक', 'ऐसी', 'समस्या', 'जिसने', 'न', 'केवल', 'भारत', 'अपितु', 'पूरे', 'विश्व', 'को', 'अपने', 'लपेटे', 'ले', 'रखा', 'है'), tags=('Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has'))),
#              ('b100-48585',
#               Sentence(words=('क्रिसमस ', 'दिसम्बर ', 'का ', 'पर्व ', 'या ', 'त्योहार ', 'है', 'सभी ', 'पर्व ', 'ओर ', 'त्योहार ', 'परस्पर ', 'प्रेम ', 'भाईचारा ', 'मिलाना ', 'मिलाप ', 'संदेश ', 'देता ', 'हे ', 'दूसरे ', 'शब्दों ', 'में ', 'सभी ', 'पर्वो  ', 'त्योहार', 'से ', 'हमे ', 'सदाचार  ', 'सहानुभूति ', 'परस्पर ', 'सहयोग ', 'और ', 'मानवता ', 'की ', 'भावना ', 'प्राप्त ', 'होती ', 'है', 'यह ', 'ध्यान ', 'देने ', 'की ', 'बात ', 'हैं', 'कि ', 'कोई ', 'भी ', 'पर्व', 'या ', 'त्योहार ', 'चाहे ', 'स्वदेशी ', 'हो ', 'या ', 'विदेशी ', 'हो', 'चाहे ', 'गरीब ', 'हो ', 'या ', 'अमीर ', 'वर्ग ', 'का ', 'क्यों ', 'ना ', 'हो ', 'उसमे ', 'उपर्युक्त ', 'विशेषता ', 'ओर ', 'श्रेष्ठता ', 'अवश्य ', 'होती ', 'है'), tags=('Christmas', 'December', 'is', 'festival', 'or', 'festival', 'is', 'everyone', 'festivals', 'and', 'festival', 'mutual', 'love', 'brotherhood', 'harmonize', 'meet', 'message', 'gives', 'does', 'other', 'words', 'in', 'everyone', 'festivals', 'festivals', 'get', 'we', 'virtue', 'sympathy', 'mutual', 'cooperation', 'and', 'humanity', 'it', 'sense', 'gives', 'get', 'does', 'it', 'worth', 'noting', 'is', 'noting', 'is', 'That', 'any', 'any', 'festival', 'or', 'festival', 'it', 'indigenous', 'be', 'or', 'foreign', 'be', 'it', 'poor', 'be', 'or', 'rich', 'class', 'it', 'be', 'whether', 'be', 'it', 'above', 'characteristic', 'and', 'superiority', 'must', 'have', 'it'))),
#              ('b100-24517',
#               Sentence(words=('इराक  ', 'के', 'विदेश', 'मंत्री', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'मजाक', 'उड़ाया', 'जिसमें', 'अमरीका', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा', 'आतंकवाद', 'एक', 'ऐसी', 'समस्या', 'जिसने', 'न', 'केवल', 'भारत', 'अपितु', 'पूरे', 'विश्व', 'को', 'अपने', 'लपेटे', 'ले', 'रखा', 'है'), tags=('Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has'))),
#              ('b100-22340',
#               Sentence(words=('क्रिसमस ', 'दिसम्बर ', 'का ', 'पर्व ', 'या ', 'त्योहार ', 'है', 'वे', 'हो', 'पर', 'एक', 'है', 'इस', 'करता है', 'ठीक कर', 'छह', 'पढ़ा', 'हाथ', 'आधा', 'किमी ', 'की ', 'लंबाई ', 'पर ', 'देश', 'विशेष', 'जहाँ ', 'केवल ', 'मां', 'के ', 'पट ', 'खुलने ', 'और ', 'बंद ', 'होने ', 'के ', 'दिन ', 'ही ', 'पूजा ', 'किया ', 'जाता ', 'है', 'पृथ्वी', 'का ', 'स्थान ', 'हवा', 'में ', 'टुकड़ा', 'अथवा ', 'घर', 'के ', 'रूप ', 'में ', 'महत्वपूर्ण ', 'है', 'सभी ', 'पर्व ', 'ओर ', 'त्योहार ', 'परस्पर ', 'प्रेम ', 'भाईचारा ', 'मिलाना ', 'मिलाप ', 'संदेश ', 'देता ', 'हे ', 'दूसरे ', 'शब्दों ', 'में ', 'सभी ', 'पर्वो  ', 'त्योहार', 'से ', 'हमे ', 'सदाचार  ', 'सहानुभूति ', 'परस्पर ', 'सहयोग ', 'और ', 'मानवता ', 'की ', 'भावना ', 'प्राप्त ', 'होती ', 'है', 'यह ', 'ध्यान ', 'देने ', 'की ', 'बात ', 'हैं', 'कि ', 'कोई ', 'भी ', 'पर्व', 'या ', 'त्योहार ', 'चाहे ', 'स्वदेशी ', 'हो ', 'या ', 'विदेशी ', 'हो', 'चाहे ', 'गरीब ', 'हो ', 'या ', 'अमीर ', 'वर्ग ', 'का ', 'क्यों ', 'ना ', 'हो ', 'उसमे ', 'उपर्युक्त ', 'विशेषता ', 'ओर ', 'श्रेष्ठता ', 'अवश्य ', 'होती ', 'है'), tags=('Christmas', 'December', 'is', 'festival', 'or', 'festival', 'is', 'they', 'be', 'at', 'one', 'have', 'this', 'does', 'fix', 'six', 'read', 'hand', 'half', 'km', 'a', 'length', 'at', 'country', 'special', 'where', 'only', 'mother', 'is', 'door', 'opening', 'and', 'closing', 'done', 'is', 'day', 'only', 'pray', 'done', 'is', 'done', 'earth', 'is', 'place', 'wind', 'as', 'piece', 'or', 'house', 'is', 'way', 'as', 'important', 'is', 'everyone', 'festivals', 'and', 'festival', 'mutual', 'love', 'brotherhood', 'harmonize', 'meet', 'message', 'gives', 'does', 'other', 'words', 'in', 'everyone', 'festivals', 'festivals', 'get', 'we', 'virtue', 'sympathy', 'mutual', 'cooperation', 'and', 'humanity', 'it', 'sense', 'gives', 'get', 'does', 'it', 'worth', 'noting', 'is', 'noting', 'is', 'That', 'any', 'any', 'festival', 'or', 'festival', 'it', 'indigenous', 'be', 'or', 'foreign', 'be', 'it', 'poor', 'be', 'or', 'rich', 'class', 'it', 'be', 'whether', 'be', 'it', 'above', 'characteristic', 'and', 'superiority', 'must', 'have', 'it'))),
#              ('b100-27528',
#               Sentence(words=('इराक  ', 'के', 'विदेश', 'मंत्री', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'मजाक', 'उड़ाया', 'जिसमें', 'अमरीका', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा', 'आतंकवाद', 'एक', 'ऐसी', 'समस्या', 'जिसने', 'न', 'केवल', 'भारत', 'अपितु', 'पूरे', 'विश्व', 'को', 'अपने', 'लपेटे', 'ले', 'रखा', 'है'), tags=('Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has'))),
#              ('b100-77722',
#               Sentence(words=('क्रिसमस', 'का', 'पर्व', 'या', 'त्योहार-पर्व', 'है', 'जिसे', 'न', 'केवल', 'ईसाई', 'धर्म', 'के', 'अनुयायी', 'समर्थक', 'ही', 'मनाते', 'है', 'अपितु', 'इसे', 'सभी', 'विशव', 'के', 'प्रायः', 'सभी', 'धर्मो', 'ओर', 'सम्प्रदाय', 'के', 'लोग', 'मनाते', 'है', 'इस', 'प्रकार', 'बिना', 'भेदभाव', 'के', 'पूरे', 'विशव', 'में', 'मनाया', 'जाता', 'है', 'इसे', 'बिना', 'कोई'), tags=('Christmas', "'s", 'festival', 'or', 'festival', 'is', 'that', 'is not', 'only', 'christian', 'religion', 'is', 'followers', 'supporters', 'only', 'celebrated', 'by', 'but', 'this', 'everyone', 'world', 'in', 'before', 'everyone', 'religions', 'and', 'communities', "'s", 'people', 'celebrate', 'it', 'In this', 'way', 'without', 'discrimination', 'in', 'whole', 'world', 'in', 'celebrated', 'is', 'is', 'this', 'without', 'any'))),
#              ('b100-54920',
#               Sentence(words=('क्रिसमस ', 'दिसम्बर ', 'का ', 'पर्व ', 'या ', 'त्योहार ', 'है', 'इसके   ', 'अतिरिक्त', 'गुग्गुल', 'कुंड', 'भीम', 'गुफा ', 'तथा', 'भीमशिला', 'भी', 'दर्शनीय', 'है', 'वे', 'हो', 'पर', 'एक', 'है', 'इस', 'करता है', 'ठीक कर', 'छह', 'पढ़ा', 'हाथ', 'वे', 'हो', 'पर', 'एक', 'है', 'इस', 'करता है', 'ठीक कर', 'छह', 'पढ़ा', 'हाथ', 'आधा', 'किमी ', 'की ', 'लंबाई ', 'पर ', 'देश', 'विशेष', 'जहाँ ', 'केवल ', 'मां', 'के ', 'पट ', 'खुलने ', 'और ', 'बंद ', 'होने ', 'के ', 'दिन ', 'ही ', 'पूजा ', 'किया ', 'जाता ', 'है', 'आधा', 'किमी ', 'की ', 'लंबाई ', 'पर ', 'देश', 'विशेष', 'जहाँ ', 'केवल ', 'मां', 'के ', 'पट ', 'खुलने ', 'और ', 'बंद ', 'होने ', 'के ', 'दिन ', 'ही ', 'पूजा ', 'किया ', 'जाता ', 'है', 'आधा', 'किमी ', 'की ', 'लंबाई ', 'पर ', 'देश', 'विशेष', 'जहाँ ', 'केवल ', 'मां', 'के ', 'पट ', 'खुलने ', 'और ', 'बंद ', 'होने ', 'के ', 'दिन ', 'ही ', 'पूजा ', 'किया ', 'जाता ', 'है'), tags=('Christmas', 'December', 'is', 'festival', 'or', 'festival', 'is', 'Apart', 'from this', 'Guggul', 'Kund', 'Bhima', 'Cave', 'and', 'Bhimshila', 'also worth', 'visiting', 'is', 'they', 'be', 'at', 'one', 'have', 'this', 'does', 'fix', 'six', 'read', 'hand', 'they', 'be', 'at', 'one', 'have', 'this', 'does', 'fix', 'six', 'read', 'hand', 'half', 'km', 'a', 'length', 'at', 'country', 'special', 'where', 'only', 'mother', 'is', 'door', 'opening', 'and', 'closing', 'done', 'is', 'day', 'only', 'pray', 'done', 'is', 'done', 'half', 'km', 'a', 'length', 'at', 'country', 'special', 'where', 'only', 'mother', 'is', 'door', 'opening', 'and', 'closing', 'done', 'is', 'day', 'only', 'pray', 'done', 'is', 'done', 'half', 'km', 'a', 'length', 'at', 'country', 'special', 'where', 'only', 'mother', 'is', 'door', 'opening', 'and', 'closing', 'done', 'is', 'day', 'only', 'pray', 'done', 'is', 'done'))),
#              ('b100-32087',
#               Sentence(words=('पृथ्वी', 'का ', 'स्थान ', 'हवा', 'में ', 'टुकड़ा', 'अथवा ', 'घर', 'के ', 'रूप ', 'में ', 'महत्वपूर्ण ', 'है', 'पृथ्वी', 'का ', 'स्थान ', 'हवा', 'में ', 'टुकड़ा', 'अथवा ', 'घर', 'के ', 'रूप ', 'में ', 'महत्वपूर्ण ', 'है', 'पृथ्वी', 'का ', 'स्थान ', 'हवा', 'में ', 'टुकड़ा', 'अथवा ', 'घर', 'के ', 'रूप ', 'में ', 'महत्वपूर्ण ', 'है', 'सभी ', 'पर्व ', 'ओर ', 'त्योहार ', 'परस्पर ', 'प्रेम ', 'भाईचारा ', 'मिलाना ', 'मिलाप ', 'संदेश ', 'देता ', 'हे ', 'दूसरे ', 'शब्दों ', 'में ', 'सभी ', 'पर्वो  ', 'त्योहार', 'से ', 'हमे ', 'सदाचार  ', 'सहानुभूति ', 'परस्पर ', 'सहयोग ', 'और ', 'मानवता ', 'की ', 'भावना ', 'प्राप्त ', 'होती ', 'है', 'यह ', 'ध्यान ', 'देने ', 'की ', 'बात ', 'हैं', 'कि ', 'कोई ', 'भी ', 'पर्व', 'या ', 'त्योहार ', 'चाहे ', 'स्वदेशी ', 'हो ', 'या ', 'विदेशी ', 'हो', 'चाहे ', 'गरीब ', 'हो ', 'या ', 'अमीर ', 'वर्ग ', 'का ', 'क्यों ', 'ना ', 'हो ', 'उसमे ', 'उपर्युक्त ', 'विशेषता ', 'ओर ', 'श्रेष्ठता ', 'अवश्य ', 'होती ', 'है'), tags=('earth', 'is', 'place', 'wind', 'as', 'piece', 'or', 'house', 'is', 'way', 'as', 'important', 'is', 'earth', 'is', 'place', 'wind', 'as', 'piece', 'or', 'house', 'is', 'way', 'as', 'important', 'is', 'earth', 'is', 'place', 'wind', 'as', 'piece', 'or', 'house', 'is', 'way', 'as', 'important', 'is', 'everyone', 'festivals', 'and', 'festival', 'mutual', 'love', 'brotherhood', 'harmonize', 'meet', 'message', 'gives', 'does', 'other', 'words', 'in', 'everyone', 'festivals', 'festivals', 'get', 'we', 'virtue', 'sympathy', 'mutual', 'cooperation', 'and', 'humanity', 'it', 'sense', 'gives', 'get', 'does', 'it', 'worth', 'noting', 'is', 'noting', 'is', 'That', 'any', 'any', 'festival', 'or', 'festival', 'it', 'indigenous', 'be', 'or', 'foreign', 'be', 'it', 'poor', 'be', 'or', 'rich', 'class', 'it', 'be', 'whether', 'be', 'it', 'above', 'characteristic', 'and', 'superiority', 'must', 'have', 'it'))),
#              ('b100-30402',
#               Sentence(words=('इराक  ', 'के', 'विदेश', 'मंत्री', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'मजाक', 'उड़ाया', 'जिसमें', 'अमरीका', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा', 'आतंकवाद', 'एक', 'ऐसी', 'समस्या', 'जिसने', 'न', 'केवल', 'भारत', 'अपितु', 'पूरे', 'विश्व', 'को', 'अपने', 'लपेटे', 'ले', 'रखा', 'है'), tags=('Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has'))),
#              ('b100-17866',
#               Sentence(words=('क्रिसमस ', 'दिसम्बर ', 'का ', 'पर्व ', 'या ', 'त्योहार ', 'है', 'सभी ', 'पर्व ', 'ओर ', 'त्योहार ', 'परस्पर ', 'प्रेम ', 'भाईचारा ', 'मिलाना ', 'मिलाप ', 'संदेश ', 'देता ', 'हे ', 'दूसरे ', 'शब्दों ', 'में ', 'सभी ', 'पर्वो  ', 'त्योहार', 'से ', 'हमे ', 'सदाचार  ', 'सहानुभूति ', 'परस्पर ', 'सहयोग ', 'और ', 'मानवता ', 'की ', 'भावना ', 'प्राप्त ', 'होती ', 'है', 'यह ', 'ध्यान ', 'देने ', 'की ', 'बात ', 'हैं', 'कि ', 'कोई ', 'भी ', 'पर्व', 'या ', 'त्योहार ', 'चाहे ', 'स्वदेशी ', 'हो ', 'या ', 'विदेशी ', 'हो', 'चाहे ', 'गरीब ', 'हो ', 'या ', 'अमीर ', 'वर्ग ', 'का ', 'क्यों ', 'ना ', 'हो ', 'उसमे ', 'उपर्युक्त ', 'विशेषता ', 'ओर ', 'श्रेष्ठता ', 'अवश्य ', 'होती ', 'है', 'इराक  ', 'के', 'विदेश', 'मंत्री', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'मजाक', 'उड़ाया', 'जिसमें', 'अमरीका', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा'), tags=('Christmas', 'December', 'is', 'festival', 'or', 'festival', 'is', 'everyone', 'festivals', 'and', 'festival', 'mutual', 'love', 'brotherhood', 'harmonize', 'meet', 'message', 'gives', 'does', 'other', 'words', 'in', 'everyone', 'festivals', 'festivals', 'get', 'we', 'virtue', 'sympathy', 'mutual', 'cooperation', 'and', 'humanity', 'it', 'sense', 'gives', 'get', 'does', 'it', 'worth', 'noting', 'is', 'noting', 'is', 'That', 'any', 'any', 'festival', 'or', 'festival', 'it', 'indigenous', 'be', 'or', 'foreign', 'be', 'it', 'poor', 'be', 'or', 'rich', 'class', 'it', 'be', 'whether', 'be', 'it', 'above', 'characteristic', 'and', 'superiority', 'must', 'have', 'it', 'Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said'))),
#              ('आतंकवाद\tTerrorism',
#               Sentence(words=('एक', 'ऐसी', 'समस्या', 'जिसने', 'न', 'केवल', 'भारत', 'अपितु', 'पूरे', 'विश्व', 'को', 'अपने', 'लपेटे', 'ले', 'रखा', 'है', 'क्रिसमस ', 'दिसम्बर ', 'का ', 'पर्व ', 'या ', 'त्योहार ', 'है', 'सभी ', 'पर्व ', 'ओर ', 'त्योहार ', 'परस्पर ', 'प्रेम ', 'भाईचारा ', 'मिलाना ', 'मिलाप ', 'संदेश ', 'देता ', 'हे ', 'दूसरे ', 'शब्दों ', 'में ', 'सभी ', 'पर्वो  ', 'त्योहार', 'से ', 'हमे ', 'सदाचार  ', 'सहानुभूति ', 'परस्पर ', 'सहयोग ', 'और ', 'मानवता ', 'की ', 'भावना ', 'प्राप्त ', 'होती ', 'है', 'यह ', 'ध्यान ', 'देने ', 'की ', 'बात ', 'हैं', 'कि ', 'कोई ', 'भी ', 'पर्व', 'या ', 'त्योहार ', 'चाहे ', 'स्वदेशी ', 'हो ', 'या ', 'विदेशी ', 'हो', 'चाहे ', 'गरीब ', 'हो ', 'या ', 'अमीर ', 'वर्ग ', 'का ', 'क्यों ', 'ना ', 'हो ', 'उसमे ', 'उपर्युक्त ', 'विशेषता ', 'ओर ', 'श्रेष्ठता ', 'अवश्य ', 'होती ', 'है'), tags=('one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has', 'Christmas', 'December', 'is', 'festival', 'or', 'festival', 'is', 'everyone', 'festivals', 'and', 'festival', 'mutual', 'love', 'brotherhood', 'harmonize', 'meet', 'message', 'gives', 'does', 'other', 'words', 'in', 'everyone', 'festivals', 'festivals', 'get', 'we', 'virtue', 'sympathy', 'mutual', 'cooperation', 'and', 'humanity', 'it', 'sense', 'gives', 'get', 'does', 'it', 'worth', 'noting', 'is', 'noting', 'is', 'That', 'any', 'any', 'festival', 'or', 'festival', 'it', 'indigenous', 'be', 'or', 'foreign', 'be', 'it', 'poor', 'be', 'or', 'rich', 'class', 'it', 'be', 'whether', 'be', 'it', 'above', 'characteristic', 'and', 'superiority', 'must', 'have', 'it'))),
#              ('इराक  \tIraq',
#               Sentence(words=('के', 'विदेश', 'मंत्री', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'मजाक', 'उड़ाया', 'जिसमें', 'अमरीका', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा', 'आतंकवाद', 'एक', 'ऐसी', 'समस्या', 'जिसने', 'न', 'केवल', 'भारत', 'अपितु', 'पूरे', 'विश्व', 'को', 'अपने', 'लपेटे', 'ले', 'रखा', 'है', 'क्रिसमस ', 'दिसम्बर ', 'का ', 'पर्व ', 'या ', 'त्योहार ', 'है'), tags=('for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has', 'Christmas', 'December', 'is', 'festival', 'or', 'festival', 'is')))])

# %% [markdown]
# The class Dataset below incorporates our function above, reads in the Brown corpus and creates a collection of keys, a set of (unique) words, a sequence of words and a mirror sequence of tags as tuples, with N being the number of words in the Brown corpus.
#
# Then it splits all this nice data into a training and test decomposition by using the Subset class defined further below, which mirrors the Dataset class.

# %%
class Dataset(namedtuple("_Dataset", "sentences keys vocab X tagset Y training_set testing_set N stream")):
    def __new__(cls, tagfile, datafile, train_test_split=0.8, seed=112890):
        tagset = read_tags(tagfile)
        sentences = read_data(datafile)
        keys = tuple(sentences.keys())
        wordset = frozenset(chain(*[s.words for s in sentences.values()]))
        word_sequences = tuple([sentences[k].words for k in keys])
        tag_sequences = tuple([sentences[k].tags for k in keys])
        N = sum(1 for _ in chain(*(s.words for s in sentences.values())))
        
        # split data into train/test sets
        _keys = list(keys)
        if seed is not None: random.seed(seed)
        random.shuffle(_keys)
        split = int(train_test_split * len(_keys))
        training_data = Subset(sentences, _keys[:split])
        testing_data = Subset(sentences, _keys[split:])
        stream = tuple(zip(chain(*word_sequences), chain(*tag_sequences)))
        return super().__new__(cls, dict(sentences), keys, wordset, word_sequences, tagset,
                               tag_sequences, training_data, testing_data, N, stream.__iter__)

    def __len__(self):
        return len(self.sentences)

    def __iter__(self):
        return iter(self.sentences.items())
    
    
class Subset(namedtuple("BaseSet", "sentences keys vocab X tagset Y N stream")):
    def __new__(cls, sentences, keys):
        word_sequences = tuple([sentences[k].words for k in keys])
        tag_sequences = tuple([sentences[k].tags for k in keys])
        wordset = frozenset(chain(*word_sequences))
        tagset = frozenset(chain(*tag_sequences))
        N = sum(1 for _ in chain(*(sentences[k].words for k in keys)))
        stream = tuple(zip(chain(*word_sequences), chain(*tag_sequences)))
        return super().__new__(cls, {k: sentences[k] for k in keys}, keys, wordset, word_sequences,
                               tagset, tag_sequences, N, stream.__iter__)

    def __len__(self):
        return len(self.sentences)

    def __iter__(self):
        return iter(self.sentences.items())

# %% [markdown]
# Let's read in the Brown corpus again, leveraging our classes above now, which order the corpus into efficiently navigable structures:

# %%
data = Dataset("english.txt", "hindi.txt", train_test_split=0.8)

print("There are {} sentences in the corpus.".format(len(data)))
print("There are {} sentences in the training set.".format(len(data.training_set)))
print("There are {} sentences in the testing set.".format(len(data.testing_set)))

assert len(data) == len(data.training_set) + len(data.testing_set), \
       "The number of sentences in the training set + testing set should sum to the number of sentences in the corpus"
# Out:
# There are 18 sentences in the corpus.
# There are 14 sentences in the training set.
# There are 4 sentences in the testing set.

# %% [markdown]
# X: Independent variable
# Y: Dependent variable

# %%
for i in range(2):    
    print("Sentence {}:".format(i + 1), data.X[i])
    print()
    print("Labels {}:".format(i + 1), data.Y[i])
    print()
# Out:
# Sentence 1: ('वे', 'हो', 'पर', 'एक', 'है', 'इस', 'करता है', 'ठीक कर', 'छह', 'पढ़ा', 'हाथ', 'वे', 'हो', 'पर', 'एक', 'है', 'इस', 'करता है', 'ठीक कर', 'छह', 'पढ़ा', 'हाथ')
#
# Labels 1: ('they', 'be', 'at', 'one', 'have', 'this', 'does', 'fix', 'six', 'read', 'hand', 'they', 'be', 'at', 'one', 'have', 'this', 'does', 'fix', 'six', 'read', 'hand')
#
# Sentence 2: ('वे', 'हो', 'पर', 'एक', 'है', 'इस', 'करता है', 'ठीक कर', 'छह', 'पढ़ा', 'हाथ', 'आधा', 'किमी ', 'की ', 'लंबाई ', 'पर ', 'देश', 'विशेष', 'जहाँ ', 'केवल ', 'मां', 'के ', 'पट ', 'खुलने ', 'और ', 'बंद ', 'होने ', 'के ', 'दिन ', 'ही ', 'पूजा ', 'किया ', 'जाता ', 'है')
#
# Labels 2: ('they', 'be', 'at', 'one', 'have', 'this', 'does', 'fix', 'six', 'read', 'hand', 'half', 'km', 'a', 'length', 'at', 'country', 'special', 'where', 'only', 'mother', 'is', 'door', 'opening', 'and', 'closing', 'done', 'is', 'day', 'only', 'pray', 'done', 'is', 'done')

# %%
# key = 'b100-87000'
# print("Sentence: {}".format(key))
# print("words:\n\t{!s}".format(data.sentences[key].words))
# print("tags:\n\t{!s}".format(data.sentences[key].tags))

# %% [markdown]
# Use Dataset.stream() to enumerate (word, tag) samples for the entire corpus.
#
#
#
# Lets Enumerate first 7

# %%
words = [word for i, (word, tag) in enumerate(data.training_set.stream())]
tags = [tag for i, (word, tag) in enumerate(data.training_set.stream())]
words[0:7], tags[0:7]
# Out:
# (['सभी ', 'पर्व ', 'ओर ', 'त्योहार ', 'परस्पर ', 'प्रेम ', 'भाईचारा '],
#  ['everyone', 'festivals', 'and', 'festival', 'mutual', 'love', 'brotherhood'])

# %% [markdown]
# #  POS Tagger using BOW Model

# %%
def pair_counts(tags, words):
    d = defaultdict(lambda: defaultdict(int))
    for tag, word in zip(tags, words):
        d[tag][word] += 1
    return d
        
word_counts = pair_counts(words, tags)

# %% [markdown]
# Let's produce a dictionary where words (keys) are associated with their most frequent Translated tag:

# %%
mfc_table = dict((word, max(tags.keys(), key=lambda key: tags[key])) for word, tags in word_counts.items())

# %%
i = 0
for key, value in mfc_table.items():
    print(key, value)
    i += 1
    if i > 3: break
# Out:
# सभी  everyone
# पर्व  festivals
# ओर  and
# त्योहार  festival

# %% [markdown]
# Python namedtuple supports a type of container-like dictionary that, like dictionaries, contains keys that are hashed to particular values. But it supports both access from key values as well as iteration, the functionality that dictionaries lack.
#
# Let's write a class that takes in a table in its constructor and adds <MISSING> English tags if the word is missing from the training set (possible that a word is in the test set but missing from the training set). It also has a viterbi method that takes in the table and builds a sequence of states that we will use in our Hidden Markov Model.

# %%
FakeState = namedtuple('FakeState', 'name')

class MFCTagger:
    missing = FakeState(name = '<MISSING>')
    
    def __init__(self, table):
        self.table = defaultdict(lambda: MFCTagger.missing)
        self.table.update({word: FakeState(name=tag) for word, tag in table.items()})
        
    def viterbi(self, seq):
        """This method simplifies predictions by matching the Pomegranate viterbi() interface"""
        return 0., list(enumerate(["<start>"] + [self.table[w] for w in seq] + ["<end>"]))

# %%
# Using Most frequent POS tag
mfc_model = MFCTagger(mfc_table)

# %%
def replace_unknown(sequence):
    return [w if w in data.training_set.vocab else 'nan' for w in sequence]

def simplify_decoding(X, model):    
    _, state_path = model.viterbi(replace_unknown(X))
    return [state[1].name for state in state_path[1:-1]]

# %%
for key in data.testing_set.keys[:2]:
    print("Sentence Key: {}\n".format(key))
    print("Sentence: {}\n".format(data.sentences[key].words))
    print("Predicted labels:\n-----------------")
    print(simplify_decoding(data.sentences[key].words, mfc_model))
    print()
    print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")
# Out:
# Sentence Key: b100-27528
#
# Sentence: ('इराक  ', 'के', 'विदेश', 'मंत्री', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'मजाक', 'उड़ाया', 'जिसमें', 'अमरीका', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा', 'आतंकवाद', 'एक', 'ऐसी', 'समस्या', 'जिसने', 'न', 'केवल', 'भारत', 'अपितु', 'पूरे', 'विश्व', 'को', 'अपने', 'लपेटे', 'ले', 'रखा', 'है')
#
# Predicted labels:
# -----------------
# ['Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'is']
#
# Actual labels:
# --------------
# ('Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has')
#
#
# Sentence Key: b100-39560
#
# Sentence: ('इराक  ', 'के', 'विदेश', 'मंत्री', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'मजाक', 'उड़ाया', 'जिसमें', 'अमरीका', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा', 'आतंकवाद', 'एक', 'ऐसी', 'समस्या', 'जिसने', 'न', 'केवल', 'भारत', 'अपितु', 'पूरे', 'विश्व', 'को', 'अपने', 'लपेटे', 'ले', 'रखा', 'है')
#
# Predicted labels:
# -----------------
# ['Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'is']
#
# Actual labels:
# --------------
# ('Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has')

# %% [markdown]
# Pretty good! Let's evaluate the accuracy of the translator

# %%
def accuracy(X, Y, model):
    
    correct = total_predictions = 0
    for observations, actual_tags in zip(X, Y):
        
        # The model.viterbi call in simplify_decoding will return None if the HMM
        # raises an error (for example, if a test sentence contains a word that
        # is out of vocabulary for the training set). Any exception counts the
        # full sentence as an error (which makes this a conservative estimate).
        try:
            most_likely_tags = simplify_decoding(observations, model)
            correct += sum(p == t for p, t in zip(most_likely_tags, actual_tags))
        except:
            pass
        total_predictions += len(observations)
    return correct / total_predictions

# %%
mfc_training_acc = accuracy(data.training_set.X, data.training_set.Y, mfc_model)
print("training accuracy mfc_model: {:.2f}%".format(100 * mfc_training_acc))

mfc_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, mfc_model)
print("testing accuracy mfc_model: {:.2f}%".format(100 * mfc_testing_acc))
# Out:
# training accuracy mfc_model: 92.75%
# testing accuracy mfc_model: 93.43%

# %% [markdown]
# # Hidden Markov Model

# %% [markdown]
# Unigram Counts

# %%
def unigram_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.training_set.stream())]
tag_unigrams = unigram_counts(tags)
tag_unigrams
# Out:
# Counter({'everyone': 14,
#          'festivals': 18,
#          'and': 27,
#          'festival': 32,
#          'mutual': 12,
#          'love': 6,
#          'brotherhood': 6,
#          'harmonize': 6,
#          'meet': 6,
#          'message': 6,
#          'gives': 12,
#          'does': 16,
#          'other': 6,
#          'words': 6,
#          'in': 14,
#          'get': 12,
#          'we': 6,
#          'virtue': 6,
#          'sympathy': 6,
#          'cooperation': 6,
#          'humanity': 6,
#          'it': 43,
#          'sense': 6,
#          'worth': 6,
#          'noting': 12,
#          'is': 71,
#          'That': 6,
#          'any': 13,
#          'or': 32,
#          'indigenous': 6,
#          'be': 34,
#          'foreign': 11,
#          'poor': 6,
#          'rich': 6,
#          'class': 6,
#          'whether': 6,
#          'above': 6,
#          'characteristic': 6,
#          'superiority': 6,
#          'must': 6,
#          'have': 10,
#          'Christmas': 7,
#          'December': 6,
#          "'s": 2,
#          'that': 10,
#          'is not': 1,
#          'only': 20,
#          'christian': 1,
#          'religion': 1,
#          'followers': 1,
#          'supporters': 1,
#          'celebrated': 2,
#          'by': 1,
#          'but': 5,
#          'this': 6,
#          'world': 6,
#          'before': 1,
#          'religions': 1,
#          'communities': 1,
#          'people': 1,
#          'celebrate': 1,
#          'In this': 1,
#          'way': 8,
#          'without': 2,
#          'discrimination': 1,
#          'whole': 5,
#          'Iraq': 9,
#          'for': 29,
#          'minister': 5,
#          'america': 10,
#          'proposal': 5,
#          'mock': 5,
#          'made': 5,
#          'united': 5,
#          'nations': 5,
#          'sanctions': 5,
#          'citizens': 5,
#          'them': 10,
#          'less': 5,
#          'harmful': 5,
#          'make': 5,
#          'said': 5,
#          'Terrorism': 4,
#          'one': 8,
#          'problem': 4,
#          'which': 4,
#          'not': 4,
#          'India': 4,
#          'our': 4,
#          'engulfed': 4,
#          'take': 4,
#          'kept': 4,
#          'has': 4,
#          'they': 4,
#          'at': 11,
#          'fix': 4,
#          'six': 4,
#          'read': 4,
#          'hand': 4,
#          'half': 7,
#          'km': 7,
#          'a': 7,
#          'length': 7,
#          'country': 7,
#          'special': 7,
#          'where': 7,
#          'mother': 7,
#          'door': 7,
#          'opening': 7,
#          'closing': 7,
#          'done': 21,
#          'day': 7,
#          'pray': 7,
#          'earth': 7,
#          'place': 7,
#          'wind': 7,
#          'as': 14,
#          'piece': 7,
#          'house': 7,
#          'important': 7,
#          'Apart': 1,
#          'from this': 1,
#          'Guggul': 1,
#          'Kund': 1,
#          'Bhima': 1,
#          'Cave': 1,
#          'Bhimshila': 1,
#          'also worth': 1,
#          'visiting': 1})

# %% [markdown]
# Bigram Counts

# %%
def bigram_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.stream())]
o = [(tags[i],tags[i+1]) for i in range(0,len(tags)-2,2)]
tag_bigrams = bigram_counts(o)
tag_bigrams
# Out:
# Counter({('they', 'be'): 4,
#          ('at', 'one'): 4,
#          ('have', 'this'): 4,
#          ('does', 'fix'): 4,
#          ('six', 'read'): 4,
#          ('hand', 'they'): 2,
#          ('be', 'at'): 2,
#          ('one', 'have'): 2,
#          ('this', 'does'): 2,
#          ('fix', 'six'): 2,
#          ('read', 'hand'): 2,
#          ('hand', 'half'): 2,
#          ('km', 'a'): 4,
#          ('length', 'at'): 4,
#          ('country', 'special'): 4,
#          ('where', 'only'): 4,
#          ('mother', 'is'): 4,
#          ('door', 'opening'): 4,
#          ('and', 'closing'): 4,
#          ('done', 'is'): 7,
#          ('day', 'only'): 4,
#          ('pray', 'done'): 4,
#          ('is', 'done'): 4,
#          ('half', 'km'): 3,
#          ('a', 'length'): 3,
#          ('at', 'country'): 3,
#          ('special', 'where'): 3,
#          ('only', 'mother'): 3,
#          ('is', 'door'): 3,
#          ('opening', 'and'): 3,
#          ('closing', 'done'): 3,
#          ('is', 'day'): 3,
#          ('only', 'pray'): 3,
#          ('done', 'half'): 2,
#          ('earth', 'is'): 4,
#          ('place', 'wind'): 4,
#          ('as', 'piece'): 4,
#          ('or', 'house'): 4,
#          ('is', 'way'): 4,
#          ('as', 'important'): 4,
#          ('is', 'earth'): 2,
#          ('is', 'place'): 3,
#          ('wind', 'as'): 3,
#          ('piece', 'or'): 3,
#          ('house', 'is'): 3,
#          ('way', 'as'): 3,
#          ('important', 'is'): 3,
#          ('is', 'everyone'): 5,
#          ('festivals', 'and'): 5,
#          ('festival', 'mutual'): 5,
#          ('love', 'brotherhood'): 5,
#          ('harmonize', 'meet'): 5,
#          ('message', 'gives'): 5,
#          ('does', 'other'): 5,
#          ('words', 'in'): 5,
#          ('everyone', 'festivals'): 7,
#          ('festivals', 'get'): 5,
#          ('we', 'virtue'): 5,
#          ('sympathy', 'mutual'): 5,
#          ('cooperation', 'and'): 5,
#          ('humanity', 'it'): 5,
#          ('sense', 'gives'): 5,
#          ('get', 'does'): 5,
#          ('it', 'worth'): 5,
#          ('noting', 'is'): 10,
#          ('That', 'any'): 5,
#          ('any', 'festival'): 5,
#          ('or', 'festival'): 11,
#          ('it', 'indigenous'): 5,
#          ('be', 'or'): 10,
#          ('foreign', 'be'): 5,
#          ('it', 'poor'): 5,
#          ('rich', 'class'): 5,
#          ('it', 'be'): 5,
#          ('whether', 'be'): 5,
#          ('it', 'above'): 5,
#          ('characteristic', 'and'): 5,
#          ('superiority', 'must'): 5,
#          ('have', 'it'): 5,
#          ('Iraq', 'for'): 4,
#          ('foreign', 'minister'): 4,
#          ('america', 'for'): 4,
#          ('that', 'proposal'): 4,
#          ('mock', 'made'): 4,
#          ('in', 'america'): 4,
#          ('united', 'nations'): 4,
#          ('for', 'sanctions'): 4,
#          ('Iraq', 'citizens'): 4,
#          ('for', 'them'): 7,
#          ('less', 'harmful'): 4,
#          ('make', 'for'): 4,
#          ('them', 'said'): 4,
#          ('Terrorism', 'one'): 3,
#          ('that', 'problem'): 3,
#          ('which', 'not'): 3,
#          ('only', 'India'): 3,
#          ('but', 'whole'): 3,
#          ('world', 'for'): 3,
#          ('our', 'engulfed'): 3,
#          ('take', 'kept'): 3,
#          ('has', 'Christmas'): 3,
#          ('December', 'is'): 2,
#          ('festival', 'or'): 4,
#          ('festival', 'is'): 2,
#          ('and', 'festival'): 2,
#          ('mutual', 'love'): 2,
#          ('brotherhood', 'harmonize'): 2,
#          ('meet', 'message'): 2,
#          ('gives', 'does'): 2,
#          ('other', 'words'): 2,
#          ('in', 'everyone'): 2,
#          ('festivals', 'festivals'): 2,
#          ('get', 'we'): 2,
#          ('virtue', 'sympathy'): 2,
#          ('mutual', 'cooperation'): 2,
#          ('and', 'humanity'): 2,
#          ('it', 'sense'): 2,
#          ('gives', 'get'): 2,
#          ('does', 'it'): 2,
#          ('worth', 'noting'): 2,
#          ('is', 'noting'): 2,
#          ('is', 'That'): 2,
#          ('any', 'any'): 2,
#          ('festival', 'it'): 2,
#          ('indigenous', 'be'): 2,
#          ('or', 'foreign'): 2,
#          ('be', 'it'): 4,
#          ('poor', 'be'): 2,
#          ('or', 'rich'): 2,
#          ('class', 'it'): 2,
#          ('be', 'whether'): 2,
#          ('above', 'characteristic'): 2,
#          ('and', 'superiority'): 2,
#          ('must', 'have'): 2,
#          ('it', 'Iraq'): 2,
#          ('for', 'foreign'): 3,
#          ('minister', 'america'): 3,
#          ('for', 'that'): 3,
#          ('proposal', 'mock'): 3,
#          ('made', 'in'): 3,
#          ('america', 'united'): 3,
#          ('nations', 'for'): 3,
#          ('sanctions', 'Iraq'): 3,
#          ('citizens', 'for'): 3,
#          ('them', 'less'): 3,
#          ('harmful', 'make'): 3,
#          ('said', 'Terrorism'): 3,
#          ('one', 'that'): 4,
#          ('problem', 'which'): 4,
#          ('not', 'only'): 4,
#          ('India', 'but'): 4,
#          ('whole', 'world'): 4,
#          ('for', 'our'): 4,
#          ('engulfed', 'take'): 4,
#          ('kept', 'has'): 4,
#          ('Christmas', 'December'): 5,
#          ('is', 'festival'): 5,
#          ("'s", 'festival'): 1,
#          ('is', 'that'): 1,
#          ('is not', 'only'): 1,
#          ('christian', 'religion'): 1,
#          ('is', 'followers'): 1,
#          ('supporters', 'only'): 1,
#          ('celebrated', 'by'): 1,
#          ('but', 'this'): 1,
#          ('everyone', 'world'): 1,
#          ('in', 'before'): 1,
#          ('everyone', 'religions'): 1,
#          ('and', 'communities'): 1,
#          ("'s", 'people'): 1,
#          ('celebrate', 'it'): 1,
#          ('In this', 'way'): 1,
#          ('without', 'discrimination'): 1,
#          ('in', 'whole'): 1,
#          ('world', 'in'): 1,
#          ('celebrated', 'is'): 1,
#          ('is', 'this'): 1,
#          ('without', 'any'): 1,
#          ('is', 'Apart'): 1,
#          ('from this', 'Guggul'): 1,
#          ('Kund', 'Bhima'): 1,
#          ('Cave', 'and'): 1,
#          ('Bhimshila', 'also worth'): 1,
#          ('visiting', 'is'): 1,
#          ('done', 'earth'): 1})

# %% [markdown]
# Beginnings of the sentences count

# %%
def starting_counts(sequences):
    return Counter(sequences)

tags = [tag for i, (word, tag) in enumerate(data.stream())]
starts_tag = [i[0] for i in data.Y]
tag_starts = starting_counts(starts_tag)
tag_starts
# Out:
# Counter({'they': 2,
#          'half': 1,
#          'everyone': 1,
#          'Iraq': 5,
#          'Christmas': 6,
#          'earth': 1,
#          'one': 1,
#          'for': 1})

# %% [markdown]
# Endings of the sentences count

# %%
def ending_counts(sequences):    
    return Counter(sequences)

end_tag = [i[len(i)-1] for i in data.Y]
tag_ends = ending_counts(end_tag)
tag_ends
# Out:
# Counter({'hand': 1,
#          'done': 2,
#          'is': 2,
#          'it': 6,
#          'has': 5,
#          'any': 1,
#          'said': 1})

# %%
end_tag = [i[len(i)-2] for i in data.Y]
tag_ends = ending_counts(end_tag)
tag_ends
# Out:
# Counter({'read': 1,
#          'is': 2,
#          'important': 1,
#          'have': 6,
#          'kept': 5,
#          'without': 1,
#          'them': 1,
#          'festival': 1})

# %% [markdown]
# Let's create our Hidden Markov Model and peek into most popular words.
#
# tag_words_count contains words associated to each English tag, arranged by frequency so that we can eventually evaluate emission probabilities, which are probabilities of observable states (words) given hidden states (English translation tags).

# %%
hmm_model = HiddenMarkovModel(name="base-hmm-tagger")

tags = [tag for i, (word, tag) in enumerate(data.stream())]
words = [word for i, (word, tag) in enumerate(data.stream())]

tags_count = unigram_counts(tags)
tag_words_count = pair_counts(tags, words)

starting_tag_list = [i[0] for i in data.Y]
#ending_tag_list = [i[-1] if len(i)==1 else i[-2] for i in data.Y]
#ending_tag_list = [i[-1] for i in data.Y]
ending_tag_list = [i[len(i)-1] for i in data.Y]

starting_tag_count = starting_counts(starting_tag_list) #the number of times a tag occured at the start
ending_tag_count = ending_counts(ending_tag_list)       #the number of times a tag occured at the end

tag_words_count
# Out:
# defaultdict(<function __main__.pair_counts.<locals>.<lambda>()>,
#             {'they': defaultdict(int, {'वे': 6}),
#              'be': defaultdict(int, {'हो': 13, 'हो ': 21, 'क्यों ': 7}),
#              'at': defaultdict(int, {'पर': 6, 'पर ': 7}),
#              'one': defaultdict(int, {'एक': 13}),
#              'have': defaultdict(int, {'है': 6, 'होती ': 7}),
#              'this': defaultdict(int, {'इस': 6, 'इसे': 2}),
#              'does': defaultdict(int, {'करता है': 6, 'हे ': 7, 'है': 7}),
#              'fix': defaultdict(int, {'ठीक कर': 6}),
#              'six': defaultdict(int, {'छह': 6}),
#              'read': defaultdict(int, {'पढ़ा': 6}),
#              'hand': defaultdict(int, {'हाथ': 6}),
#              'half': defaultdict(int, {'आधा': 7}),
#              'km': defaultdict(int, {'किमी ': 7}),
#              'a': defaultdict(int, {'की ': 7}),
#              'length': defaultdict(int, {'लंबाई ': 7}),
#              'country': defaultdict(int, {'देश': 7}),
#              'special': defaultdict(int, {'विशेष': 7}),
#              'where': defaultdict(int, {'जहाँ ': 7}),
#              'only': defaultdict(int,
#                          {'केवल ': 7, 'ही ': 7, 'केवल': 8, 'ही': 1}),
#              'mother': defaultdict(int, {'मां': 7}),
#              'is': defaultdict(int,
#                          {'के ': 21,
#                           'जाता ': 7,
#                           'का ': 14,
#                           'है': 17,
#                           'की ': 7,
#                           'हैं': 7,
#                           'के': 1,
#                           'जाता': 1}),
#              'door': defaultdict(int, {'पट ': 7}),
#              'opening': defaultdict(int, {'खुलने ': 7}),
#              'and': defaultdict(int,
#                          {'और ': 14, 'ओर ': 14, 'ओर': 1, 'तथा': 1}),
#              'closing': defaultdict(int, {'बंद ': 7}),
#              'done': defaultdict(int, {'होने ': 7, 'किया ': 7, 'है': 7}),
#              'day': defaultdict(int, {'दिन ': 7}),
#              'pray': defaultdict(int, {'पूजा ': 7}),
#              'earth': defaultdict(int, {'पृथ्वी': 7}),
#              'place': defaultdict(int, {'स्थान ': 7}),
#              'wind': defaultdict(int, {'हवा': 7}),
#              'as': defaultdict(int, {'में ': 14}),
#              'piece': defaultdict(int, {'टुकड़ा': 7}),
#              'or': defaultdict(int, {'अथवा ': 7, 'या ': 28, 'या': 1}),
#              'house': defaultdict(int, {'घर': 7}),
#              'way': defaultdict(int, {'रूप ': 7, 'प्रकार': 1}),
#              'important': defaultdict(int, {'महत्वपूर्ण ': 7}),
#              'everyone': defaultdict(int, {'सभी ': 14, 'सभी': 2}),
#              'festivals': defaultdict(int,
#                          {'पर्व ': 7, 'पर्वो  ': 7, 'त्योहार': 7}),
#              'festival': defaultdict(int,
#                          {'त्योहार ': 21,
#                           'पर्व': 8,
#                           'पर्व ': 7,
#                           'त्योहार-पर्व': 1}),
#              'mutual': defaultdict(int, {'परस्पर ': 14}),
#              'love': defaultdict(int, {'प्रेम ': 7}),
#              'brotherhood': defaultdict(int, {'भाईचारा ': 7}),
#              'harmonize': defaultdict(int, {'मिलाना ': 7}),
#              'meet': defaultdict(int, {'मिलाप ': 7}),
#              'message': defaultdict(int, {'संदेश ': 7}),
#              'gives': defaultdict(int, {'देता ': 7, 'प्राप्त ': 7}),
#              'other': defaultdict(int, {'दूसरे ': 7}),
#              'words': defaultdict(int, {'शब्दों ': 7}),
#              'in': defaultdict(int,
#                          {'में ': 7, 'जिसमें': 7, 'के': 2, 'में': 1}),
#              'get': defaultdict(int, {'से ': 7, 'होती ': 7}),
#              'we': defaultdict(int, {'हमे ': 7}),
#              'virtue': defaultdict(int, {'सदाचार  ': 7}),
#              'sympathy': defaultdict(int, {'सहानुभूति ': 7}),
#              'cooperation': defaultdict(int, {'सहयोग ': 7}),
#              'humanity': defaultdict(int, {'मानवता ': 7}),
#              'it': defaultdict(int,
#                          {'की ': 7,
#                           'यह ': 7,
#                           'चाहे ': 14,
#                           'का ': 7,
#                           'उसमे ': 7,
#                           'है': 8}),
#              'sense': defaultdict(int, {'भावना ': 7}),
#              'worth': defaultdict(int, {'ध्यान ': 7}),
#              'noting': defaultdict(int, {'देने ': 7, 'बात ': 7}),
#              'That': defaultdict(int, {'कि ': 7}),
#              'any': defaultdict(int, {'कोई ': 7, 'भी ': 7, 'कोई': 1}),
#              'indigenous': defaultdict(int, {'स्वदेशी ': 7}),
#              'foreign': defaultdict(int, {'विदेशी ': 7, 'विदेश': 7}),
#              'poor': defaultdict(int, {'गरीब ': 7}),
#              'rich': defaultdict(int, {'अमीर ': 7}),
#              'class': defaultdict(int, {'वर्ग ': 7}),
#              'whether': defaultdict(int, {'ना ': 7}),
#              'above': defaultdict(int, {'उपर्युक्त ': 7}),
#              'characteristic': defaultdict(int, {'विशेषता ': 7}),
#              'superiority': defaultdict(int, {'श्रेष्ठता ': 7}),
#              'must': defaultdict(int, {'अवश्य ': 7}),
#              'Iraq': defaultdict(int, {'इराक  ': 6, 'इराकी': 7}),
#              'for': defaultdict(int, {'के': 35, 'को': 7}),
#              'minister': defaultdict(int, {'मंत्री': 7}),
#              'america': defaultdict(int, {'अमरीका': 14}),
#              'that': defaultdict(int, {'उस': 7, 'ऐसी': 7, 'जिसे': 1}),
#              'proposal': defaultdict(int, {'प्रस्ताव': 7}),
#              'mock': defaultdict(int, {'मजाक': 7}),
#              'made': defaultdict(int, {'उड़ाया': 7}),
#              'united': defaultdict(int, {'संयुक्त': 7}),
#              'nations': defaultdict(int, {'राष्ट्र': 7}),
#              'sanctions': defaultdict(int, {'प्रतिबंधों': 7}),
#              'citizens': defaultdict(int, {'नागरिकों': 7}),
#              'them': defaultdict(int, {'लिए': 14}),
#              'less': defaultdict(int, {'कम': 7}),
#              'harmful': defaultdict(int, {'हानिकारक': 7}),
#              'make': defaultdict(int, {'बनाने': 7}),
#              'said': defaultdict(int, {'कहा': 7}),
#              'Terrorism': defaultdict(int, {'आतंकवाद': 6}),
#              'problem': defaultdict(int, {'समस्या': 7}),
#              'which': defaultdict(int, {'जिसने': 7}),
#              'not': defaultdict(int, {'न': 7}),
#              'India': defaultdict(int, {'भारत': 7}),
#              'but': defaultdict(int, {'अपितु': 8}),
#              'whole': defaultdict(int, {'पूरे': 8}),
#              'world': defaultdict(int, {'विश्व': 7, 'विशव': 2}),
#              'our': defaultdict(int, {'अपने': 7}),
#              'engulfed': defaultdict(int, {'लपेटे': 7}),
#              'take': defaultdict(int, {'ले': 7}),
#              'kept': defaultdict(int, {'रखा': 7}),
#              'has': defaultdict(int, {'है': 7}),
#              'Christmas': defaultdict(int, {'क्रिसमस ': 7, 'क्रिसमस': 1}),
#              'December': defaultdict(int, {'दिसम्बर ': 7}),
#              "'s": defaultdict(int, {'का': 1, 'के': 1}),
#              'is not': defaultdict(int, {'न': 1}),
#              'christian': defaultdict(int, {'ईसाई': 1}),
#              'religion': defaultdict(int, {'धर्म': 1}),
#              'followers': defaultdict(int, {'अनुयायी': 1}),
#              'supporters': defaultdict(int, {'समर्थक': 1}),
#              'celebrated': defaultdict(int, {'मनाते': 1, 'मनाया': 1}),
#              'by': defaultdict(int, {'है': 1}),
#              'before': defaultdict(int, {'प्रायः': 1}),
#              'religions': defaultdict(int, {'धर्मो': 1}),
#              'communities': defaultdict(int, {'सम्प्रदाय': 1}),
#              'people': defaultdict(int, {'लोग': 1}),
#              'celebrate': defaultdict(int, {'मनाते': 1}),
#              'In this': defaultdict(int, {'इस': 1}),
#              'without': defaultdict(int, {'बिना': 2}),
#              'discrimination': defaultdict(int, {'भेदभाव': 1}),
#              'Apart': defaultdict(int, {'इसके   ': 1}),
#              'from this': defaultdict(int, {'अतिरिक्त': 1}),
#              'Guggul': defaultdict(int, {'गुग्गुल': 1}),
#              'Kund': defaultdict(int, {'कुंड': 1}),
#              'Bhima': defaultdict(int, {'भीम': 1}),
#              'Cave': defaultdict(int, {'गुफा ': 1}),
#              'Bhimshila': defaultdict(int, {'भीमशिला': 1}),
#              'also worth': defaultdict(int, {'भी': 1}),
#              'visiting': defaultdict(int, {'दर्शनीय': 1})})

# %%
to_pass_states = []
dist = []
for tag, words_dict in tag_words_count.items():
    total = float(sum(words_dict.values()))
    distribution = {word: count/total for word, count in words_dict.items()}
    dist.append(distribution)
    tag_emissions = DiscreteDistribution(distribution)
    tag_state = State(tag_emissions, name=tag)
    to_pass_states.append(tag_state)

# %% [markdown]
# Let's convert word frequencies by English tag to probabilities by dividing by the total number of words per English tag, yielding the distribution of words.
#
# We'll define HMM emission probabilities using that distribution.

# %%
dist
# Out:
# [{'वे': 1.0},
#  {'हो': 0.3170731707317073,
#   'हो ': 0.5121951219512195,
#   'क्यों ': 0.17073170731707318},
#  {'पर': 0.46153846153846156, 'पर ': 0.5384615384615384},
#  {'एक': 1.0},
#  {'है': 0.46153846153846156, 'होती ': 0.5384615384615384},
#  {'इस': 0.75, 'इसे': 0.25},
#  {'करता है': 0.3, 'हे ': 0.35, 'है': 0.35},
#  {'ठीक कर': 1.0},
#  {'छह': 1.0},
#  {'पढ़ा': 1.0},
#  {'हाथ': 1.0},
#  {'आधा': 1.0},
#  {'किमी ': 1.0},
#  {'की ': 1.0},
#  {'लंबाई ': 1.0},
#  {'देश': 1.0},
#  {'विशेष': 1.0},
#  {'जहाँ ': 1.0},
#  {'केवल ': 0.30434782608695654,
#   'ही ': 0.30434782608695654,
#   'केवल': 0.34782608695652173,
#   'ही': 0.043478260869565216},
#  {'मां': 1.0},
#  {'के ': 0.28,
#   'जाता ': 0.09333333333333334,
#   'का ': 0.18666666666666668,
#   'है': 0.22666666666666666,
#   'की ': 0.09333333333333334,
#   'हैं': 0.09333333333333334,
#   'के': 0.013333333333333334,
#   'जाता': 0.013333333333333334},
#  {'पट ': 1.0},
#  {'खुलने ': 1.0},
#  {'और ': 0.4666666666666667,
#   'ओर ': 0.4666666666666667,
#   'ओर': 0.03333333333333333,
#   'तथा': 0.03333333333333333},
#  {'बंद ': 1.0},
#  {'होने ': 0.3333333333333333,
#   'किया ': 0.3333333333333333,
#   'है': 0.3333333333333333},
#  {'दिन ': 1.0},
#  {'पूजा ': 1.0},
#  {'पृथ्वी': 1.0},
#  {'स्थान ': 1.0},
#  {'हवा': 1.0},
#  {'में ': 1.0},
#  {'टुकड़ा': 1.0},
#  {'अथवा ': 0.19444444444444445,
#   'या ': 0.7777777777777778,
#   'या': 0.027777777777777776},
#  {'घर': 1.0},
#  {'रूप ': 0.875, 'प्रकार': 0.125},
#  {'महत्वपूर्ण ': 1.0},
#  {'सभी ': 0.875, 'सभी': 0.125},
#  {'पर्व ': 0.3333333333333333,
#   'पर्वो  ': 0.3333333333333333,
#   'त्योहार': 0.3333333333333333},
#  {'त्योहार ': 0.5675675675675675,
#   'पर्व': 0.21621621621621623,
#   'पर्व ': 0.1891891891891892,
#   'त्योहार-पर्व': 0.02702702702702703},
#  {'परस्पर ': 1.0},
#  {'प्रेम ': 1.0},
#  {'भाईचारा ': 1.0},
#  {'मिलाना ': 1.0},
#  {'मिलाप ': 1.0},
#  {'संदेश ': 1.0},
#  {'देता ': 0.5, 'प्राप्त ': 0.5},
#  {'दूसरे ': 1.0},
#  {'शब्दों ': 1.0},
#  {'में ': 0.4117647058823529,
#   'जिसमें': 0.4117647058823529,
#   'के': 0.11764705882352941,
#   'में': 0.058823529411764705},
#  {'से ': 0.5, 'होती ': 0.5},
#  {'हमे ': 1.0},
#  {'सदाचार  ': 1.0},
#  {'सहानुभूति ': 1.0},
#  {'सहयोग ': 1.0},
#  {'मानवता ': 1.0},
#  {'की ': 0.14,
#   'यह ': 0.14,
#   'चाहे ': 0.28,
#   'का ': 0.14,
#   'उसमे ': 0.14,
#   'है': 0.16},
#  {'भावना ': 1.0},
#  {'ध्यान ': 1.0},
#  {'देने ': 0.5, 'बात ': 0.5},
#  {'कि ': 1.0},
#  {'कोई ': 0.4666666666666667,
#   'भी ': 0.4666666666666667,
#   'कोई': 0.06666666666666667},
#  {'स्वदेशी ': 1.0},
#  {'विदेशी ': 0.5, 'विदेश': 0.5},
#  {'गरीब ': 1.0},
#  {'अमीर ': 1.0},
#  {'वर्ग ': 1.0},
#  {'ना ': 1.0},
#  {'उपर्युक्त ': 1.0},
#  {'विशेषता ': 1.0},
#  {'श्रेष्ठता ': 1.0},
#  {'अवश्य ': 1.0},
#  {'इराक  ': 0.46153846153846156, 'इराकी': 0.5384615384615384},
#  {'के': 0.8333333333333334, 'को': 0.16666666666666666},
#  {'मंत्री': 1.0},
#  {'अमरीका': 1.0},
#  {'उस': 0.4666666666666667,
#   'ऐसी': 0.4666666666666667,
#   'जिसे': 0.06666666666666667},
#  {'प्रस्ताव': 1.0},
#  {'मजाक': 1.0},
#  {'उड़ाया': 1.0},
#  {'संयुक्त': 1.0},
#  {'राष्ट्र': 1.0},
#  {'प्रतिबंधों': 1.0},
#  {'नागरिकों': 1.0},
#  {'लिए': 1.0},
#  {'कम': 1.0},
#  {'हानिकारक': 1.0},
#  {'बनाने': 1.0},
#  {'कहा': 1.0},
#  {'आतंकवाद': 1.0},
#  {'समस्या': 1.0},
#  {'जिसने': 1.0},
#  {'न': 1.0},
#  {'भारत': 1.0},
#  {'अपितु': 1.0},
#  {'पूरे': 1.0},
#  {'विश्व': 0.7777777777777778, 'विशव': 0.2222222222222222},
#  {'अपने': 1.0},
#  {'लपेटे': 1.0},
#  {'ले': 1.0},
#  {'रखा': 1.0},
#  {'है': 1.0},
#  {'क्रिसमस ': 0.875, 'क्रिसमस': 0.125},
#  {'दिसम्बर ': 1.0},
#  {'का': 0.5, 'के': 0.5},
#  {'न': 1.0},
#  {'ईसाई': 1.0},
#  {'धर्म': 1.0},
#  {'अनुयायी': 1.0},
#  {'समर्थक': 1.0},
#  {'मनाते': 0.5, 'मनाया': 0.5},
#  {'है': 1.0},
#  {'प्रायः': 1.0},
#  {'धर्मो': 1.0},
#  {'सम्प्रदाय': 1.0},
#  {'लोग': 1.0},
#  {'मनाते': 1.0},
#  {'इस': 1.0},
#  {'बिना': 1.0},
#  {'भेदभाव': 1.0},
#  {'इसके   ': 1.0},
#  {'अतिरिक्त': 1.0},
#  {'गुग्गुल': 1.0},
#  {'कुंड': 1.0},
#  {'भीम': 1.0},
#  {'गुफा ': 1.0},
#  {'भीमशिला': 1.0},
#  {'भी': 1.0},
#  {'दर्शनीय': 1.0}]

# %%
to_pass_states
# Out:
# [{
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "they",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u094b" : 0.3170731707317073,
#                  "\u0939\u094b " : 0.5121951219512195,
#                  "\u0915\u094d\u092f\u094b\u0902 " : 0.17073170731707318
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "be",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u0930" : 0.46153846153846156,
#                  "\u092a\u0930 " : 0.5384615384615384
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "at",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u090f\u0915" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "one",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0948" : 0.46153846153846156,
#                  "\u0939\u094b\u0924\u0940 " : 0.5384615384615384
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "have",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0907\u0938" : 0.75,
#                  "\u0907\u0938\u0947" : 0.25
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "this",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0930\u0924\u093e \u0939\u0948" : 0.3,
#                  "\u0939\u0947 " : 0.35,
#                  "\u0939\u0948" : 0.35
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "does",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0920\u0940\u0915 \u0915\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "fix",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091b\u0939" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "six",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u0922\u093c\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "read",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u093e\u0925" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "hand",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0906\u0927\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "half",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u093f\u092e\u0940 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "km",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0940 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "a",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0932\u0902\u092c\u093e\u0908 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "length",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0947\u0936" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "country",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u093f\u0936\u0947\u0937" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "special",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091c\u0939\u093e\u0901 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "where",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0947\u0935\u0932 " : 0.30434782608695654,
#                  "\u0939\u0940 " : 0.30434782608695654,
#                  "\u0915\u0947\u0935\u0932" : 0.34782608695652173,
#                  "\u0939\u0940" : 0.043478260869565216
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "only",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u093e\u0902" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "mother",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0947 " : 0.28,
#                  "\u091c\u093e\u0924\u093e " : 0.09333333333333334,
#                  "\u0915\u093e " : 0.18666666666666668,
#                  "\u0939\u0948" : 0.22666666666666666,
#                  "\u0915\u0940 " : 0.09333333333333334,
#                  "\u0939\u0948\u0902" : 0.09333333333333334,
#                  "\u0915\u0947" : 0.013333333333333334,
#                  "\u091c\u093e\u0924\u093e" : 0.013333333333333334
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "is",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u091f " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "door",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0916\u0941\u0932\u0928\u0947 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "opening",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0914\u0930 " : 0.4666666666666667,
#                  "\u0913\u0930 " : 0.4666666666666667,
#                  "\u0913\u0930" : 0.03333333333333333,
#                  "\u0924\u0925\u093e" : 0.03333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "and",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0902\u0926 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "closing",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u094b\u0928\u0947 " : 0.3333333333333333,
#                  "\u0915\u093f\u092f\u093e " : 0.3333333333333333,
#                  "\u0939\u0948" : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "done",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u093f\u0928 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "day",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u0942\u091c\u093e " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "pray",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u0943\u0925\u094d\u0935\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "earth",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u094d\u0925\u093e\u0928 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "place",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0935\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "wind",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0947\u0902 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "as",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091f\u0941\u0915\u0921\u093c\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "piece",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u0925\u0935\u093e " : 0.19444444444444445,
#                  "\u092f\u093e " : 0.7777777777777778,
#                  "\u092f\u093e" : 0.027777777777777776
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "or",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0918\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "house",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0930\u0942\u092a " : 0.875,
#                  "\u092a\u094d\u0930\u0915\u093e\u0930" : 0.125
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "way",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0939\u0924\u094d\u0935\u092a\u0942\u0930\u094d\u0923 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "important",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u092d\u0940 " : 0.875,
#                  "\u0938\u092d\u0940" : 0.125
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "everyone",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u0930\u094d\u0935 " : 0.3333333333333333,
#                  "\u092a\u0930\u094d\u0935\u094b  " : 0.3333333333333333,
#                  "\u0924\u094d\u092f\u094b\u0939\u093e\u0930" : 0.3333333333333333
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "festivals",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0924\u094d\u092f\u094b\u0939\u093e\u0930 " : 0.5675675675675675,
#                  "\u092a\u0930\u094d\u0935" : 0.21621621621621623,
#                  "\u092a\u0930\u094d\u0935 " : 0.1891891891891892,
#                  "\u0924\u094d\u092f\u094b\u0939\u093e\u0930-\u092a\u0930\u094d\u0935" : 0.02702702702702703
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "festival",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u0930\u0938\u094d\u092a\u0930 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "mutual",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u094d\u0930\u0947\u092e " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "love",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092d\u093e\u0908\u091a\u093e\u0930\u093e " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "brotherhood",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u093f\u0932\u093e\u0928\u093e " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "harmonize",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u093f\u0932\u093e\u092a " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "meet",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0902\u0926\u0947\u0936 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "message",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0947\u0924\u093e " : 0.5,
#                  "\u092a\u094d\u0930\u093e\u092a\u094d\u0924 " : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "gives",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0942\u0938\u0930\u0947 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "other",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0936\u092c\u094d\u0926\u094b\u0902 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "words",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0947\u0902 " : 0.4117647058823529,
#                  "\u091c\u093f\u0938\u092e\u0947\u0902" : 0.4117647058823529,
#                  "\u0915\u0947" : 0.11764705882352941,
#                  "\u092e\u0947\u0902" : 0.058823529411764705
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "in",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0947 " : 0.5,
#                  "\u0939\u094b\u0924\u0940 " : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "get",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u092e\u0947 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "we",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0926\u093e\u091a\u093e\u0930  " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "virtue",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0939\u093e\u0928\u0941\u092d\u0942\u0924\u093f " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "sympathy",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0939\u092f\u094b\u0917 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "cooperation",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u093e\u0928\u0935\u0924\u093e " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "humanity",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0940 " : 0.14,
#                  "\u092f\u0939 " : 0.14,
#                  "\u091a\u093e\u0939\u0947 " : 0.28,
#                  "\u0915\u093e " : 0.14,
#                  "\u0909\u0938\u092e\u0947 " : 0.14,
#                  "\u0939\u0948" : 0.16
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "it",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092d\u093e\u0935\u0928\u093e " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "sense",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0927\u094d\u092f\u093e\u0928 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "worth",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0947\u0928\u0947 " : 0.5,
#                  "\u092c\u093e\u0924 " : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "noting",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u093f " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "That",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u094b\u0908 " : 0.4666666666666667,
#                  "\u092d\u0940 " : 0.4666666666666667,
#                  "\u0915\u094b\u0908" : 0.06666666666666667
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "any",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u094d\u0935\u0926\u0947\u0936\u0940 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "indigenous",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u093f\u0926\u0947\u0936\u0940 " : 0.5,
#                  "\u0935\u093f\u0926\u0947\u0936" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "foreign",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0917\u0930\u0940\u092c " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "poor",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u092e\u0940\u0930 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "rich",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u0930\u094d\u0917 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "class",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0928\u093e " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "whether",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u092a\u0930\u094d\u092f\u0941\u0915\u094d\u0924 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "above",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u093f\u0936\u0947\u0937\u0924\u093e " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "characteristic",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0936\u094d\u0930\u0947\u0937\u094d\u0920\u0924\u093e " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "superiority",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u0935\u0936\u094d\u092f " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "must",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0907\u0930\u093e\u0915  " : 0.46153846153846156,
#                  "\u0907\u0930\u093e\u0915\u0940" : 0.5384615384615384
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Iraq",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0947" : 0.8333333333333334,
#                  "\u0915\u094b" : 0.16666666666666666
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "for",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0902\u0924\u094d\u0930\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "minister",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u092e\u0930\u0940\u0915\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "america",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u0938" : 0.4666666666666667,
#                  "\u0910\u0938\u0940" : 0.4666666666666667,
#                  "\u091c\u093f\u0938\u0947" : 0.06666666666666667
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "that",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u094d\u0930\u0938\u094d\u0924\u093e\u0935" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "proposal",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u091c\u093e\u0915" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "mock",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0909\u095c\u093e\u092f\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "made",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u0902\u092f\u0941\u0915\u094d\u0924" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "united",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0930\u093e\u0937\u094d\u091f\u094d\u0930" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "nations",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u094d\u0930\u0924\u093f\u092c\u0902\u0927\u094b\u0902" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "sanctions",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0928\u093e\u0917\u0930\u093f\u0915\u094b\u0902" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "citizens",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0932\u093f\u090f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "them",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u092e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "less",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u093e\u0928\u093f\u0915\u093e\u0930\u0915" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "harmful",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u0928\u093e\u0928\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "make",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0939\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "said",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0906\u0924\u0902\u0915\u0935\u093e\u0926" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Terrorism",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u092e\u0938\u094d\u092f\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "problem",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u091c\u093f\u0938\u0928\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "which",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0928" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "not",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092d\u093e\u0930\u0924" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "India",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u092a\u093f\u0924\u0941" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "but",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u0942\u0930\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "whole",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0935\u093f\u0936\u094d\u0935" : 0.7777777777777778,
#                  "\u0935\u093f\u0936\u0935" : 0.2222222222222222
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "world",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u092a\u0928\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "our",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0932\u092a\u0947\u091f\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "engulfed",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0932\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "take",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0930\u0916\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "kept",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0948" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "has",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u094d\u0930\u093f\u0938\u092e\u0938 " : 0.875,
#                  "\u0915\u094d\u0930\u093f\u0938\u092e\u0938" : 0.125
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Christmas",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u093f\u0938\u092e\u094d\u092c\u0930 " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "December",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u093e" : 0.5,
#                  "\u0915\u0947" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "'s",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0928" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "is not",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0908\u0938\u093e\u0908" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "christian",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0927\u0930\u094d\u092e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "religion",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u0928\u0941\u092f\u093e\u092f\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "followers",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u092e\u0930\u094d\u0925\u0915" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "supporters",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0928\u093e\u0924\u0947" : 0.5,
#                  "\u092e\u0928\u093e\u092f\u093e" : 0.5
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "celebrated",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0939\u0948" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "by",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092a\u094d\u0930\u093e\u092f\u0903" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "before",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0927\u0930\u094d\u092e\u094b" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "religions",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0938\u092e\u094d\u092a\u094d\u0930\u0926\u093e\u092f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "communities",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0932\u094b\u0917" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "people",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092e\u0928\u093e\u0924\u0947" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "celebrate",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0907\u0938" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "In this",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092c\u093f\u0928\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "without",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092d\u0947\u0926\u092d\u093e\u0935" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "discrimination",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0907\u0938\u0915\u0947   " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Apart",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0905\u0924\u093f\u0930\u093f\u0915\u094d\u0924" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "from this",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0917\u0941\u0917\u094d\u0917\u0941\u0932" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Guggul",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0915\u0941\u0902\u0921" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Kund",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092d\u0940\u092e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Bhima",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0917\u0941\u092b\u093e " : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Cave",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092d\u0940\u092e\u0936\u093f\u0932\u093e" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "Bhimshila",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u092d\u0940" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "also worth",
#      "weight" : 1.0
#  }, {
#      "class" : "State",
#      "distribution" : {
#          "class" : "Distribution",
#          "dtype" : "str",
#          "name" : "DiscreteDistribution",
#          "parameters" : [
#              {
#                  "\u0926\u0930\u094d\u0936\u0928\u0940\u092f" : 1.0
#              }
#          ],
#          "frozen" : false
#      },
#      "name" : "visiting",
#      "weight" : 1.0
#  }]

# %%
start_prob={}

for tag in tags:
    start_prob[tag] = starting_tag_count[tag] / tags_count[tag]

for tag_state in to_pass_states :
    hmm_model.add_transition(hmm_model.start, tag_state, start_prob[tag_state.name])

# %%
end_prob={}

for tag in tags:
    end_prob[tag] = ending_tag_count[tag]/tags_count[tag]
    
for tag_state in to_pass_states :
    hmm_model.add_transition(tag_state, hmm_model.end, end_prob[tag_state.name])

# %% [markdown]
# We now add the transition probabilities for our model, which uses our POS bigrams to enumerate what the probabilities are for transiting from one POS tag to another.

# %%
transition_prob_pair={}

for key in tag_bigrams.keys():
    transition_prob_pair[key] = tag_bigrams.get(key)/tags_count[key[0]]
    
for tag_state in to_pass_states:
    for next_tag_state in to_pass_states:
        if((tag_state.name,next_tag_state.name) in transition_prob_pair):
            hmm_model.add_transition(tag_state, next_tag_state, transition_prob_pair[(tag_state.name, next_tag_state.name)])

# %%
hmm_model.bake()

# %% [markdown]
# We can now compare the HMM model accuracy with the BOW model accuracy

# %%
hmm_training_acc = accuracy(data.training_set.X, data.training_set.Y, hmm_model)
print("training accuracy basic hmm model: {:.2f}%".format(100 * hmm_training_acc))

hmm_testing_acc = accuracy(data.testing_set.X, data.testing_set.Y, hmm_model)
print("testing accuracy basic hmm model: {:.2f}%".format(100 * hmm_testing_acc))
# Out:
# training accuracy basic hmm model: 72.21%
# testing accuracy basic hmm model: 100.00%

# %% [markdown]
# Decoding Example for a random sample

# %%
for key in data.testing_set.keys[:3]:
    print("Sentence Key: {}\n".format(key))
    print("Sentence: {}\n".format(data.sentences[key].words))
    print("Predicted labels:\n-----------------")
    print(simplify_decoding(data.sentences[key].words, hmm_model))
    print()
    print("Actual labels:\n--------------")
    print(data.sentences[key].tags)
    print("\n")
# Out:
# Sentence Key: b100-27528
#
# Sentence: ('इराक  ', 'के', 'विदेश', 'मंत्री', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'मजाक', 'उड़ाया', 'जिसमें', 'अमरीका', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा', 'आतंकवाद', 'एक', 'ऐसी', 'समस्या', 'जिसने', 'न', 'केवल', 'भारत', 'अपितु', 'पूरे', 'विश्व', 'को', 'अपने', 'लपेटे', 'ले', 'रखा', 'है')
#
# Predicted labels:
# -----------------
# ['Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has']
#
# Actual labels:
# --------------
# ('Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has')
#
#
# Sentence Key: b100-39560
#
# Sentence: ('इराक  ', 'के', 'विदेश', 'मंत्री', 'अमरीका', 'के', 'उस', 'प्रस्ताव', 'मजाक', 'उड़ाया', 'जिसमें', 'अमरीका', 'संयुक्त', 'राष्ट्र', 'के', 'प्रतिबंधों', 'इराकी', 'नागरिकों', 'के', 'लिए', 'कम', 'हानिकारक', 'बनाने', 'के', 'लिए', 'कहा', 'आतंकवाद', 'एक', 'ऐसी', 'समस्या', 'जिसने', 'न', 'केवल', 'भारत', 'अपितु', 'पूरे', 'विश्व', 'को', 'अपने', 'लपेटे', 'ले', 'रखा', 'है')
#
# Predicted labels:
# -----------------
# ['Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has']
#
# Actual labels:
# --------------
# ('Iraq', 'for', 'foreign', 'minister', 'america', 'for', 'that', 'proposal', 'mock', 'made', 'in', 'america', 'united', 'nations', 'for', 'sanctions', 'Iraq', 'citizens', 'for', 'them', 'less', 'harmful', 'make', 'for', 'them', 'said', 'Terrorism', 'one', 'that', 'problem', 'which', 'not', 'only', 'India', 'but', 'whole', 'world', 'for', 'our', 'engulfed', 'take', 'kept', 'has')
#
#
# Sentence Key: b100-5507
#
# Sentence: ('वे', 'हो', 'पर', 'एक', 'है', 'इस', 'करता है', 'ठीक कर', 'छह', 'पढ़ा', 'हाथ', 'वे', 'हो', 'पर', 'एक', 'है', 'इस', 'करता है', 'ठीक कर', 'छह', 'पढ़ा', 'हाथ')
#
# Predicted labels:
# -----------------
# ['they', 'be', 'at', 'one', 'have', 'this', 'does', 'fix', 'six', 'read', 'hand', 'they', 'be', 'at', 'one', 'have', 'this', 'does', 'fix', 'six', 'read', 'hand']
#
# Actual labels:
# --------------
# ('they', 'be', 'at', 'one', 'have', 'this', 'does', 'fix', 'six', 'read', 'hand', 'they', 'be', 'at', 'one', 'have', 'this', 'does', 'fix', 'six', 'read', 'hand')
