# %% [markdown]
# # Assignment 2 : Netflix Stocks

# %% [markdown]
# ## Plotting closing prices

# %%
import pandas as pd
pd.core.common.is_list_like = pd.api.types.is_list_like
import pandas_datareader as web
import datetime
start = datetime.datetime(2014, 1, 1)
end = datetime.datetime(2019, 1, 30)
nflx = web.DataReader('NFLX', 'yahoo', start, end)
nflx.head(10)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2014-01-02  52.511429  51.542858  52.401428  51.831429  12325600.0  51.831429
# 2014-01-03  52.495716  51.842857  52.000000  51.871429  10817100.0  51.871429
# 2014-01-06  52.044285  50.475716  51.889999  51.367142  15501500.0  51.367142
# 2014-01-07  49.698570  48.152859  49.684284  48.500000  36167600.0  48.500000
# 2014-01-08  49.425713  48.074287  48.104286  48.712856  20001100.0  48.712856
# 2014-01-09  49.139999  47.857143  48.824287  48.150002  17007200.0  48.150002
# 2014-01-10  48.377144  47.218571  48.295715  47.448570  16237900.0  47.448570
# 2014-01-13  49.810001  47.304287  47.304287  48.115715  27237000.0  48.115715
# 2014-01-14  48.799999  47.509998  48.777142  48.279999  19740000.0  48.279999
# 2014-01-15  48.367142  45.581429  47.857143  47.197144  40432000.0  47.197144

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
high = nflx['High']
high.plot()

# %%
close = nflx['Close']
close.plot()

# %%
import numpy as np
returns = np.diff(close)
plt.plot(returns)

# %%
import numpy as np
returns = np.diff(np.log(close))
plt.plot(returns)

# %%
high.corr(close)
# a value of 0.3 essentially means little correlation..
# Out:
# 0.9995904149031909

# %% [markdown]
# # 1. Exploratory Data Analysis(EDA)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Plot closing price
plt.figure(figsize=(16, 7))
plt.plot(nflx.Close)
plt.title('Closing price of Target')
plt.ylabel('Closing price ($)')
plt.xlabel('Trading day')
plt.grid(True)
plt.show()

# %% [markdown]
# # 2. Moving Average

# %%
def plot_moving_average(series, window, plot_intervals=False, scale=1.96):
    rolling_mean = series.rolling(window=window).mean()
 
    plt.figure(figsize=(16,7))
    plt.title('Moving average\n window size = {}'.format(window))
    plt.plot(rolling_mean, 'g', label='Rolling mean trend')

    #Plot confidence intervals for smoothed values
    if plot_intervals:
        mae = mean_absolute_error(series[window:], rolling_mean[window:])
        deviation = np.std(series[window:] - rolling_mean[window:])
        lower_bound = rolling_mean - (mae + scale * deviation)
        upper_bound = rolling_mean + (mae + scale * deviation)
        plt.plot(upper_bound, 'r--', label='Upper bound / Lower bound')
        plt.plot(lower_bound, 'r--')

    plt.plot(series[window:], label='Actual values')
    plt.legend(loc='best')
    plt.grid(True)

#Smooth by the previous 5 days (by week)
plot_moving_average(nflx.Close, 5)

# %%
#Smooth by the previous month
plot_moving_average(nflx.Close, 30)

# %%
#Smooth by the previous quarter
plot_moving_average(nflx.Close, 90)

# %% [markdown]
# # 3. Exponential Smoothing

# %%
def exponential_smoothing(series, alpha):
    result = [series[0]] # first value is same as series
    for n in range(1, len(series)):
        result.append(alpha * series[n] + (1 - alpha) * result[n-1])
    return result

def plot_exponential_smoothing(series, alphas):
    plt.figure(figsize=(17, 8))
    for alpha in alphas:
        plt.plot(exponential_smoothing(series, alpha), label="Alpha {}".format(alpha))
    plt.plot(series.values, "c", label = "Actual")
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("Exponential Smoothing")
    plt.grid(True);
        
plot_exponential_smoothing(nflx.Close, [0.05, 0.3])

# %% [markdown]
# # 4. Double Exponential Smoothing

# %%
def double_exponential_smoothing(series, alpha, beta):
    result = [series[0]]
    
    for n in range(1, len(series)+1):
        if n == 1:
            level, trend = series[0], series[1] - series[0]
        if n >= len(series): # forecasting
            value = result[-1]
        else:
            value = series[n]
        
        last_level, level = level, alpha * value + (1 - alpha) * (level + trend)
        trend = beta * (level - last_level) + (1 - beta) * trend
        result.append(level + trend)
    return result

def plot_double_exponential_smoothing(series, alphas, betas):
    plt.figure(figsize=(17, 8))
    for alpha in alphas:
        for beta in betas:
            plt.plot(double_exponential_smoothing(series, alpha, beta), label="Alpha {}, beta {}".format(alpha, beta))
    plt.plot(series.values, label = "Actual")
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("Double Exponential Smoothing")
    plt.grid(True)

plot_double_exponential_smoothing(nflx.Close, alphas=[0.9, 0.02], betas=[0.9, 0.02])

# %% [markdown]
# # 5. Modeling

# %%
import statsmodels.api as sm
import statsmodels as smt
def tsplot(y, lags=None, figsize=(12, 7), syle='bmh'):
    
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
        
    with plt.style.context(style='bmh'):
        fig = plt.figure(figsize=figsize)
        layout = (2,2)
        ts_ax = plt.subplot2grid(layout, (0,0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1,0))
        pacf_ax = plt.subplot2grid(layout, (1,1))
        
        y.plot(ax=ts_ax)
        p_value = sm.tsa.stattools.adfuller(y)[1]
        ts_ax.set_title('Time Series Analysis Plots\n Dickey-Fuller: p={0:.5f}'.format(p_value))
        smt.graphics.tsaplots.plot_acf(y, lags=lags, ax=acf_ax)
        smt.graphics.tsaplots.plot_pacf(y, lags=lags, ax=pacf_ax)
        plt.tight_layout()
        
tsplot(nflx.Close, lags=30)

# %% [markdown]
# # 6. Prediction of Stock using Random Forest

# %%
nflx.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2014-01-02  52.511429  51.542858  52.401428  51.831429  12325600.0  51.831429
# 2014-01-03  52.495716  51.842857  52.000000  51.871429  10817100.0  51.871429
# 2014-01-06  52.044285  50.475716  51.889999  51.367142  15501500.0  51.367142
# 2014-01-07  49.698570  48.152859  49.684284  48.500000  36167600.0  48.500000
# 2014-01-08  49.425713  48.074287  48.104286  48.712856  20001100.0  48.712856

# %%
dfreg = nflx.loc[:,['Adj Close', 'Volume']]
dfreg['HighLow_PCT'] = (nflx['High'] - nflx['Low']) / nflx['Close'] * 100.0
dfreg['PCT_change'] = (nflx['Close'] - nflx['Open']) / nflx['Open'] * 100.0
dfreg
# Out:
#              Adj Close      Volume  HighLow_PCT  PCT_change
# Date
# 2014-01-02   51.831429  12325600.0     1.868694   -1.087756
# 2014-01-03   51.871429  10817100.0     1.258609   -0.247251
# 2014-01-06   51.367142  15501500.0     3.053643   -1.007627
# 2014-01-07   48.500000  36167600.0     3.187034   -2.383619
# 2014-01-08   48.712856  20001100.0     2.774268    1.265106
# ...                ...         ...          ...         ...
# 2019-01-25  338.049988  11152900.0     3.398903    2.838278
# 2019-01-28  335.660004   8652100.0     2.210565    0.286821
# 2019-01-29  328.899994   7655200.0     3.061723   -2.075208
# 2019-01-30  340.660004   9234500.0     3.223158    2.377161
# 2019-01-31  339.500000   8535500.0     2.326950   -0.052989
#
# [1279 rows x 4 columns]

# %%
dfreg.fillna(value=-99999, inplace=True)

# %%
import math
forecast = int(math.ceil(0.594 * len(dfreg)))
forecast
# Out:
# 760

# %%
forecast_col = 'Adj Close'
dfreg['label'] = dfreg[forecast_col].shift(-forecast)
X = np.array(dfreg.drop(['label'], 1))
dfreg
# Out:
#              Adj Close      Volume  HighLow_PCT  PCT_change       label
# Date
# 2014-01-02   51.831429  12325600.0     1.868694   -1.087756  130.949997
# 2014-01-03   51.871429  10817100.0     1.258609   -0.247251  129.889999
# 2014-01-06   51.367142  15501500.0     3.053643   -1.007627  130.500000
# 2014-01-07   48.500000  36167600.0     3.187034   -2.383619  129.179993
# 2014-01-08   48.712856  20001100.0     2.774268    1.265106  133.699997
# ...                ...         ...          ...         ...         ...
# 2019-01-25  338.049988  11152900.0     3.398903    2.838278         NaN
# 2019-01-28  335.660004   8652100.0     2.210565    0.286821         NaN
# 2019-01-29  328.899994   7655200.0     3.061723   -2.075208         NaN
# 2019-01-30  340.660004   9234500.0     3.223158    2.377161         NaN
# 2019-01-31  339.500000   8535500.0     2.326950   -0.052989         NaN
#
# [1279 rows x 5 columns]

# %%
dfreg.tail(700)
# Out:
#              Adj Close      Volume  HighLow_PCT  PCT_change  label
# Date
# 2016-04-21   94.980003  19919400.0     2.737417   -2.394404    NaN
# 2016-04-22   95.900002  15806300.0     2.586031    1.107014    NaN
# 2016-04-25   93.559998  14985400.0     3.153054   -2.236154    NaN
# 2016-04-26   92.430000  15330900.0     2.488373   -1.144385    NaN
# 2016-04-27   91.040001  12218900.0     2.515379   -1.236710    NaN
# ...                ...         ...          ...         ...    ...
# 2019-01-25  338.049988  11152900.0     3.398903    2.838278    NaN
# 2019-01-28  335.660004   8652100.0     2.210565    0.286821    NaN
# 2019-01-29  328.899994   7655200.0     3.061723   -2.075208    NaN
# 2019-01-30  340.660004   9234500.0     3.223158    2.377161    NaN
# 2019-01-31  339.500000   8535500.0     2.326950   -0.052989    NaN
#
# [700 rows x 5 columns]

# %%
from sklearn import preprocessing
X = preprocessing.scale(X)

# %%
X_lately = X[-forecast:]
X = X[:-forecast]
X
# Out:
# array([[-0.9973961 , -0.1449508 , -0.66461681, -0.53125032],
#        [-0.99698969, -0.29296628, -1.00061664, -0.13494748],
#        [-1.00211323,  0.16667158, -0.012014  , -0.49346905],
#        ...,
#        [-0.48412992,  1.69009771,  1.75542252, -2.61704644],
#        [-0.50069061,  1.27743036,  1.46128282, -1.81938191],
#        [-0.51694652,  0.63957539,  0.35094155, -0.3302452 ]])

# %%
import numpy as np
y = np.array(dfreg['label'])
y
y = y[:-forecast]
y
# Out:
# array([130.94999695, 129.88999939, 130.5       , 129.17999268,
#        133.69999695, 132.88999939, 133.25999451, 138.41000366,
#        138.6000061 , 137.38999939, 140.11000061, 139.52000427,
#        138.96000671, 142.44999695, 141.22000122, 140.71000671,
#        140.77999878, 139.19999695, 140.25      , 140.97000122,
#        144.        , 144.74000549, 144.13999939, 144.82000732,
#        143.19999695, 140.82000732, 142.27000427, 142.00999451,
#        142.22000122, 142.6000061 , 143.86000061, 142.77999878,
#        143.25      , 143.41000366, 142.13000488, 142.6499939 ,
#        139.52999878, 139.13999939, 141.94000244, 141.42999268,
#        140.32000732, 140.52999878, 140.88999939, 143.52000427,
#        143.19000244, 145.25      , 144.38999939, 145.11000061,
#        145.83000183, 142.41999817, 142.6499939 , 141.83999634,
#        142.02000427, 144.05999756, 145.16999817, 146.47000122,
#        148.05999756, 147.80999756, 146.91999817, 145.5       ,
#        143.61999512, 143.74000549, 143.11000061, 143.8500061 ,
#        144.3500061 , 143.83000183, 142.91999817, 147.25      ,
#        143.36000061, 139.75999451, 141.17999268, 142.86999512,
#        143.83000183, 152.16000366, 150.16999817, 153.08000183,
#        152.19999695, 155.3500061 , 156.44999695, 155.58999634,
#        157.25      , 156.6000061 , 156.38000488, 157.46000671,
#        160.27999878, 158.53999329, 160.80999756, 160.02000427,
#        159.41000366, 153.19999695, 155.69999695, 157.02000427,
#        157.16000366, 157.94999695, 157.75      , 163.05000305,
#        162.42999268, 163.22000122, 163.07000732, 162.99000549,
#        165.17999268, 165.05999756, 165.16999817, 165.61000061,
#        165.88000488, 158.02999878, 151.44000244, 152.72000122,
#        152.19999695, 151.75999451, 152.38000488, 153.3999939 ,
#        152.05000305, 155.02999878, 154.88999939, 158.02000427,
#        157.5       , 151.02999878, 153.41000366, 150.08999634,
#        149.41000366, 146.16999817, 147.61000061, 146.25      ,
#        150.17999268, 152.66999817, 154.33000183, 158.75      ,
#        158.21000671, 161.11999512, 161.69999695, 183.6000061 ,
#        183.86000061, 183.6000061 , 188.53999329, 187.91000366,
#        186.97000122, 189.08000183, 182.67999268, 184.03999329,
#        181.66000366, 182.02999878, 180.74000549, 179.22999573,
#        180.27000427, 181.33000183, 178.36000061, 175.77999878,
#        169.13999939, 171.3999939 , 171.        , 168.5       ,
#        169.97999573, 166.08999634, 166.53999329, 166.75999451,
#        169.33999634, 169.05999756, 168.13000488, 165.94999695,
#        167.11999512, 168.80999756, 174.69000244, 174.71000671,
#        174.74000549, 174.52000427, 179.25      , 179.        ,
#        176.41999817, 181.74000549, 185.1499939 , 183.63999939,
#        182.63000488, 182.3500061 , 184.61999512, 185.67999268,
#        185.50999451, 188.77999878, 187.3500061 , 178.55000305,
#        179.38000488, 181.97000122, 180.69999695, 181.3500061 ,
#        177.00999451, 179.19000244, 184.44999695, 194.38999939,
#        198.02000427, 196.86999512, 195.08000183, 194.94999695,
#        195.86000061, 199.49000549, 202.67999268, 199.47999573,
#        195.53999329, 195.13000488, 194.16000366, 192.47000122,
#        196.02000427, 193.77000427, 195.21000671, 199.53999329,
#        198.36999512, 196.42999268, 198.        , 199.32000732,
#        200.00999451, 200.13000488, 195.88999939, 196.44000244,
#        193.8999939 , 192.02000427, 195.08000183, 195.71000671,
#        192.11999512, 195.50999451, 193.19999695, 194.1000061 ,
#        196.22999573, 196.32000732, 195.75      , 195.05000305,
#        199.17999268, 188.1499939 , 187.58000183, 186.82000732,
#        184.03999329, 184.21000671, 185.30000305, 185.19999695,
#        188.53999329, 186.22000122, 185.72999573, 187.86000061,
#        189.55999756, 190.11999512, 190.41999817, 187.02000427,
#        188.82000732, 188.61999512, 189.94000244, 187.75999451,
#        186.24000549, 192.71000671, 191.96000671, 201.07000732,
#        205.05000305, 205.63000488, 209.99000549, 212.05000305,
#        209.30999756, 212.52000427, 217.24000549, 221.22999573,
#        221.52999878, 217.5       , 220.33000183, 220.46000671,
#        227.58000183, 250.28999329, 261.29998779, 269.70001221,
#        274.6000061 , 284.58999634, 278.79998779, 270.29998779,
#        265.07000732, 267.42999268, 254.25999451, 265.72000122,
#        264.55999756, 250.1000061 , 249.47000122, 257.95001221,
#        258.26998901, 266.        , 280.26998901, 278.51998901,
#        278.54998779, 281.04000854, 278.14001465, 285.92999268,
#        294.16000366, 290.60998535, 291.38000488, 290.39001465,
#        301.04998779, 315.        , 325.22000122, 321.16000366,
#        317.        , 331.44000244, 321.29998779, 315.88000488,
#        321.54998779, 321.08999634, 318.45001221, 313.48001099,
#        317.5       , 316.48001099, 306.70001221, 300.94000244,
#        320.3500061 , 300.69000244, 285.76998901, 295.3500061 ,
#        280.29000854, 283.67001343, 288.94000244, 293.97000122,
#        288.8500061 , 289.92999268, 298.07000732, 303.67001343,
#        309.25      , 311.6499939 , 307.77999878, 336.05999756,
#        334.51998901, 332.70001221, 327.76998901, 318.69000244,
#        307.01998901, 305.76000977, 313.98001099, 311.76000977,
#        312.45999146, 313.29998779, 313.35998535, 311.69000244,
#        320.08999634, 326.26000977, 326.89001465, 330.29998779,
#        329.6000061 , 326.45999146, 328.52999878, 326.13000488,
#        328.19000244, 325.22000122, 324.17999268, 331.82000732,
#        331.61999512, 344.72000122, 349.29000854, 351.29000854,
#        349.73001099, 353.54000854, 351.6000061 , 359.92999268,
#        361.80999756, 365.79998779, 367.45001221, 361.3999939 ,
#        360.57000732, 361.45001221, 363.82998657, 379.92999268,
#        392.86999512, 391.98001099, 390.3999939 , 404.98001099,
#        416.76000977, 415.44000244, 411.08999634, 384.48001099,
#        399.39001465, 390.39001465, 395.42001343, 391.42999268,
#        398.17999268, 390.51998901, 398.39001465, 408.25      ,
#        418.97000122, 415.63000488, 418.6499939 , 413.5       ,
#        395.79998779, 400.48001099, 379.48001099, 375.13000488,
#        364.23001099, 361.04998779, 362.66000366, 357.32000732,
#        362.86999512, 363.08999634, 355.20999146, 334.95999146,
#        337.45001221, 338.38000488, 344.5       , 343.08999634,
#        350.92001343, 351.82998657, 347.60998535, 349.35998535,
#        345.86999512, 341.30999756, 337.48999023, 326.3999939 ,
#        322.44000244, 316.77999878, 327.73001099, 338.01998901,
#        344.44000244, 339.17001343, 358.82000732, 364.57998657,
#        368.48999023, 368.04000854, 370.98001099, 367.67999268,
#        363.6000061 , 341.17999268, 346.45999146, 348.67999268,
#        348.41000366, 355.92999268, 369.95001221, 368.1499939 ,
#        364.55999756, 350.3500061 , 367.6499939 , 366.95999146,
#        365.35998535, 361.19000244, 369.60998535, 369.42999268,
#        377.88000488, 380.70999146, 374.13000488, 381.42999268,
#        377.14001465, 377.04998779, 363.6499939 , 351.3500061 ,
#        349.1000061 , 355.70999146, 325.89001465, 321.1000061 ,
#        339.55999756, 333.13000488, 346.3999939 , 364.70001221,
#        346.70999146, 332.67001343, 329.54000854, 333.16000366,
#        301.82998657, 312.86999512, 299.82998657, 284.83999634,
#        285.80999756, 301.77999878, 317.38000488, 309.1000061 ,
#        315.44000244, 310.83999634, 327.5       , 317.92001343,
#        303.47000122, 294.07000732, 294.3999939 , 286.73001099,
#        290.05999756, 286.20999146, 270.6000061 , 266.98001099,
#        262.13000488, 258.82000732, 261.42999268, 266.63000488,
#        282.6499939 , 288.75      , 286.13000488, 290.29998779,
#        275.32998657, 282.88000488, 265.14001465, 269.70001221,
#        265.32000732, 274.88000488, 276.01998901, 266.83999634,
#        262.79998779, 270.94000244, 266.76998901, 260.57998657,
#        246.38999939, 233.88000488, 253.66999817, 255.57000732,
#        256.07998657, 267.66000366, 267.66000366, 271.20001221,
#        297.57000732, 315.33999634, 320.26998901, 319.95999146,
#        324.66000366, 337.58999634, 332.94000244, 354.64001465,
#        351.39001465, 353.19000244, 339.1000061 , 325.16000366,
#        321.98999023, 326.67001343, 338.04998779, 335.66000366,
#        328.8999939 , 340.66000366, 339.5       ])

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.model_selection import train_test_split
rf_model = RandomForestRegressor()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
rf_model.score(X_test, y_test)
# Out:
# 0.7293775121916883

# %%
dfreg.tail(761)
# Out:
#              Adj Close      Volume  HighLow_PCT  PCT_change  label
# Date
# 2016-01-25   99.120003  20321100.0     3.712672   -0.661451  339.5
# 2016-01-26   97.830002  22083900.0     5.826438   -1.914975    NaN
# 2016-01-27   91.150002  25556200.0     7.964895   -5.651588    NaN
# 2016-01-28   94.410004  24562300.0     5.444338    0.607425    NaN
# 2016-01-29   91.839996  20463900.0     4.094079   -0.173917    NaN
# ...                ...         ...          ...         ...    ...
# 2019-01-25  338.049988  11152900.0     3.398903    2.838278    NaN
# 2019-01-28  335.660004   8652100.0     2.210565    0.286821    NaN
# 2019-01-29  328.899994   7655200.0     3.061723   -2.075208    NaN
# 2019-01-30  340.660004   9234500.0     3.223158    2.377161    NaN
# 2019-01-31  339.500000   8535500.0     2.326950   -0.052989    NaN
#
# [761 rows x 5 columns]

# %% [markdown]
# After going 761 days in the past, we can predict the future by maintaining 72% accuracy
