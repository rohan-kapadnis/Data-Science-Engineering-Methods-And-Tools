# %% [markdown]
# # Assignment 2 : Target stocks

# %% [markdown]
# ## Plotting closing prices

# %%
import pandas as pd
pd.core.common.is_list_like = pd.api.types.is_list_like
import pandas_datareader as web
import datetime
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2019, 1, 30)
tgt = web.DataReader('TGT', 'yahoo', start, end)
tgt.head(10)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2010-01-04  48.889999  48.400002  48.470001  48.549999   4589100.0  36.634708
# 2010-01-05  49.230000  48.259998  48.509998  48.730000   4760100.0  36.770542
# 2010-01-06  49.700001  48.590000  48.590000  49.660000   7217400.0  37.472309
# 2010-01-07  50.790001  49.720001  50.200001  50.270000  12531000.0  37.932594
# 2010-01-08  50.110001  49.580002  50.049999  50.070000   6512800.0  37.781670
# 2010-01-11  50.330002  49.740002  50.160000  50.180000   3751700.0  37.864677
# 2010-01-12  49.980000  48.959999  49.900002  49.340000   5472000.0  37.230831
# 2010-01-13  49.660000  49.110001  49.330002  49.340000   4793400.0  37.230831
# 2010-01-14  50.349998  49.599998  49.770000  50.099998   7498700.0  37.804321
# 2010-01-15  50.320000  49.790001  49.860001  50.169998   9093100.0  37.857132

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
high = tgt['High']
high.plot()

# %%
close = tgt['Close']
close.plot()

# %%
import numpy as np
returns = np.diff(close)
plt.plot(returns)

# %%
import numpy as np
returns = np.diff(np.log(close))
plt.plot(returns)

# %%
high.corr(close)
# a value of 0.3 essentially means little correlation..
# Out:
# 0.9986853070144571

# %% [markdown]
# # 1. Exploratory Data Analysis(EDA)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Plot closing price
plt.figure(figsize=(16, 7))
plt.plot(tgt.Close)
plt.title('Closing price of Target')
plt.ylabel('Closing price ($)')
plt.xlabel('Trading day')
plt.grid(True)
plt.show()

# %% [markdown]
# # 2. Moving Average

# %%
def plot_moving_average(series, window, plot_intervals=False, scale=1.96):
    rolling_mean = series.rolling(window=window).mean()
 
    plt.figure(figsize=(16,7))
    plt.title('Moving average\n window size = {}'.format(window))
    plt.plot(rolling_mean, 'g', label='Rolling mean trend')

    #Plot confidence intervals for smoothed values
    if plot_intervals:
        mae = mean_absolute_error(series[window:], rolling_mean[window:])
        deviation = np.std(series[window:] - rolling_mean[window:])
        lower_bound = rolling_mean - (mae + scale * deviation)
        upper_bound = rolling_mean + (mae + scale * deviation)
        plt.plot(upper_bound, 'r--', label='Upper bound / Lower bound')
        plt.plot(lower_bound, 'r--')

    plt.plot(series[window:], label='Actual values')
    plt.legend(loc='best')
    plt.grid(True)

#Smooth by the previous 5 days (by week)
plot_moving_average(tgt.Close, 5)

# %%
#Smooth by the previous month
plot_moving_average(tgt.Close, 30)

# %%
#Smooth by the previous quarter
plot_moving_average(tgt.Close, 90)

# %% [markdown]
# # 3. Exponential Smoothing

# %%
def exponential_smoothing(series, alpha):
    result = [series[0]] # first value is same as series
    for n in range(1, len(series)):
        result.append(alpha * series[n] + (1 - alpha) * result[n-1])
    return result

def plot_exponential_smoothing(series, alphas):
    plt.figure(figsize=(17, 8))
    for alpha in alphas:
        plt.plot(exponential_smoothing(series, alpha), label="Alpha {}".format(alpha))
    plt.plot(series.values, "c", label = "Actual")
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("Exponential Smoothing")
    plt.grid(True);
        
plot_exponential_smoothing(tgt.Close, [0.05, 0.3])

# %% [markdown]
# # 4. Double Exponential Smoothing

# %%
def double_exponential_smoothing(series, alpha, beta):
    result = [series[0]]
    
    for n in range(1, len(series)+1):
        if n == 1:
            level, trend = series[0], series[1] - series[0]
        if n >= len(series): # forecasting
            value = result[-1]
        else:
            value = series[n]
        
        last_level, level = level, alpha * value + (1 - alpha) * (level + trend)
        trend = beta * (level - last_level) + (1 - beta) * trend
        result.append(level + trend)
    return result

def plot_double_exponential_smoothing(series, alphas, betas):
    plt.figure(figsize=(17, 8))
    for alpha in alphas:
        for beta in betas:
            plt.plot(double_exponential_smoothing(series, alpha, beta), label="Alpha {}, beta {}".format(alpha, beta))
    plt.plot(series.values, label = "Actual")
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("Double Exponential Smoothing")
    plt.grid(True)

plot_double_exponential_smoothing(tgt.Close, alphas=[0.9, 0.02], betas=[0.9, 0.02])

# %% [markdown]
# # 5. Modeling

# %%
import statsmodels.api as sm
import statsmodels as smt
def tsplot(y, lags=None, figsize=(12, 7), syle='bmh'):
    
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
        
    with plt.style.context(style='bmh'):
        fig = plt.figure(figsize=figsize)
        layout = (2,2)
        ts_ax = plt.subplot2grid(layout, (0,0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1,0))
        pacf_ax = plt.subplot2grid(layout, (1,1))
        
        y.plot(ax=ts_ax)
        p_value = sm.tsa.stattools.adfuller(y)[1]
        ts_ax.set_title('Time Series Analysis Plots\n Dickey-Fuller: p={0:.5f}'.format(p_value))
        smt.graphics.tsaplots.plot_acf(y, lags=lags, ax=acf_ax)
        smt.graphics.tsaplots.plot_pacf(y, lags=lags, ax=pacf_ax)
        plt.tight_layout()
        
tsplot(tgt.Close, lags=30)

# %% [markdown]
# # 6. Prediction of Stock using Random Forest

# %%
tgt.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2010-01-04  48.889999  48.400002  48.470001  48.549999   4589100.0  36.634708
# 2010-01-05  49.230000  48.259998  48.509998  48.730000   4760100.0  36.770542
# 2010-01-06  49.700001  48.590000  48.590000  49.660000   7217400.0  37.472309
# 2010-01-07  50.790001  49.720001  50.200001  50.270000  12531000.0  37.932594
# 2010-01-08  50.110001  49.580002  50.049999  50.070000   6512800.0  37.781670

# %%
dfreg = tgt.loc[:,['Adj Close', 'Volume']]
dfreg['HighLow_PCT'] = (tgt['High'] - tgt['Low']) / tgt['Close'] * 100.0
dfreg['PCT_change'] = (tgt['Close'] - tgt['Open']) / tgt['Open'] * 100.0
dfreg
# Out:
#             Adj Close      Volume  HighLow_PCT  PCT_change
# Date
# 2010-01-04  36.634708   4589100.0     1.009264    0.165046
# 2010-01-05  36.770542   4760100.0     1.990563    0.453517
# 2010-01-06  37.472309   7217400.0     2.235201    2.202099
# 2010-01-07  37.932594  12531000.0     2.128505    0.139442
# 2010-01-08  37.781670   6512800.0     1.058516    0.039961
# ...               ...         ...          ...         ...
# 2019-01-25  70.155190   5544200.0     2.072109    1.885991
# 2019-01-28  69.893517   3511100.0     1.400447    0.138859
# 2019-01-29  69.486481   3320600.0     1.241282   -0.582371
# 2019-01-30  70.097023   3789300.0     1.852625    0.041492
# 2019-01-31  70.746346   6699400.0     1.369863    0.954228
#
# [2285 rows x 4 columns]

# %%
dfreg.fillna(value=-99999, inplace=True)

# %%
import math
forecast = int(math.ceil(0.04 * len(dfreg)))
forecast
# Out:
# 92

# %%
forecast_col = 'Adj Close'
dfreg['label'] = dfreg[forecast_col].shift(-forecast)
X = np.array(dfreg.drop(['label'], 1))
dfreg
# Out:
#             Adj Close      Volume  HighLow_PCT  PCT_change      label
# Date
# 2010-01-04  36.634708   4589100.0     1.009264    0.165046  42.438068
# 2010-01-05  36.770542   4760100.0     1.990563    0.453517  41.177402
# 2010-01-06  37.472309   7217400.0     2.235201    2.202099  41.033089
# 2010-01-07  37.932594  12531000.0     2.128505    0.139442  40.083786
# 2010-01-08  37.781670   6512800.0     1.058516    0.039961  41.276115
# ...               ...         ...          ...         ...        ...
# 2019-01-25  70.155190   5544200.0     2.072109    1.885991        NaN
# 2019-01-28  69.893517   3511100.0     1.400447    0.138859        NaN
# 2019-01-29  69.486481   3320600.0     1.241282   -0.582371        NaN
# 2019-01-30  70.097023   3789300.0     1.852625    0.041492        NaN
# 2019-01-31  70.746346   6699400.0     1.369863    0.954228        NaN
#
# [2285 rows x 5 columns]

# %%
dfreg.tail(700)
# Out:
#             Adj Close     Volume  HighLow_PCT  PCT_change      label
# Date
# 2016-04-21  72.682961  3328900.0     1.365556   -0.397210  62.617439
# 2016-04-22  72.314056  3208300.0     1.190326   -0.675591  62.965366
# 2016-04-25  72.551208  3163700.0     1.210654    0.547775  63.170547
# 2016-04-26  72.551208  2933800.0     0.823245   -0.048404  62.537155
# 2016-04-27  73.157272  3580200.0     1.644859    0.749973  62.715576
# ...               ...        ...          ...         ...        ...
# 2019-01-25  70.155190  5544200.0     2.072109    1.885991        NaN
# 2019-01-28  69.893517  3511100.0     1.400447    0.138859        NaN
# 2019-01-29  69.486481  3320600.0     1.241282   -0.582371        NaN
# 2019-01-30  70.097023  3789300.0     1.852625    0.041492        NaN
# 2019-01-31  70.746346  6699400.0     1.369863    0.954228        NaN
#
# [700 rows x 5 columns]

# %%
from sklearn import preprocessing
X = preprocessing.scale(X)

# %%
X_lately = X[-forecast:]
X = X[:-forecast]
X
# Out:
# array([[-1.53608686, -0.35573311, -0.78150053,  0.13209438],
#        [-1.52452362, -0.30403921,  0.22985955,  0.3763733 ],
#        [-1.46478368,  0.43881133,  0.48199179,  1.85708302],
#        ...,
#        [ 2.54062291, -0.70513557, -0.67315313, -0.1806428 ],
#        [ 2.48662043, -0.87926242, -0.55818801, -0.87195355],
#        [ 2.51934938, -0.2272541 , -0.27008963,  0.6934608 ]])

# %%
import numpy as np
y = np.array(dfreg['label'])
y
y = y[:-forecast]
y
# Out:
# array([42.43806839, 41.1774025 , 41.03308868, ..., 69.48648071,
#        70.09702301, 70.74634552])

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.model_selection import train_test_split
rf_model = RandomForestRegressor()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
rf_model.score(X_test, y_test)
# Out:
# 0.7266945336887056

# %%
 dfreg.tail(93)
# Out:
#             Adj Close     Volume  HighLow_PCT  PCT_change      label
# Date
# 2018-09-18  84.274048  5014100.0     1.505474    0.827968  70.746346
# 2018-09-19  83.774254  3218500.0     1.789818   -0.593062        NaN
# 2018-09-20  83.985710  3242100.0     1.052870    0.011439        NaN
# 2018-09-21  83.918427  6707500.0     1.832558   -0.251344        NaN
# 2018-09-24  83.851135  3475700.0     1.707930    0.034398        NaN
# ...               ...        ...          ...         ...        ...
# 2019-01-25  70.155190  5544200.0     2.072109    1.885991        NaN
# 2019-01-28  69.893517  3511100.0     1.400447    0.138859        NaN
# 2019-01-29  69.486481  3320600.0     1.241282   -0.582371        NaN
# 2019-01-30  70.097023  3789300.0     1.852625    0.041492        NaN
# 2019-01-31  70.746346  6699400.0     1.369863    0.954228        NaN
#
# [93 rows x 5 columns]

# %% [markdown]
# After going 92 days in the past, we can predict the future by maintaining 72% accuracy
